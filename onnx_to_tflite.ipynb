# %%
# !pip install onnx2tf
# Out:
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# Collecting onnx2tf
#   Obtaining dependency information for onnx2tf from https://files.pythonhosted.org/packages/21/70/69cad3947e44af12c2c3a81f93ab0131b4ff2887f46f1acf10a89cf1fd90/onnx2tf-1.18.14-py3-none-any.whl.metadata
#   Downloading onnx2tf-1.18.14-py3-none-any.whl.metadata (129 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.2/129.2 kB 1.3 MB/s eta 0:00:001.3 MB/s eta 0:00:01
# Downloading onnx2tf-1.18.14-py3-none-any.whl (407 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 407.1/407.1 kB 3.0 MB/s eta 0:00:00 MB/s eta 0:00:01
# Installing collected packages: onnx2tf
# Successfully installed onnx2tf-1.18.14

# %%
# !pip install tensorflow
# Out:
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# Collecting tensorflow
#   Obtaining dependency information for tensorflow from https://files.pythonhosted.org/packages/d7/3f/41f868253756f696fd00771885be60cf680352a818f08dda6e0ed8c96eea/tensorflow-2.15.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata
#   Downloading tensorflow-2.15.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.4 kB)
# Collecting absl-py>=1.0.0 (from tensorflow)
#   Obtaining dependency information for absl-py>=1.0.0 from https://files.pythonhosted.org/packages/01/e4/dc0a1dcc4e74e08d7abedab278c795eef54a224363bb18f5692f416d834f/absl_py-2.0.0-py3-none-any.whl.metadata
#   Downloading absl_py-2.0.0-py3-none-any.whl.metadata (2.3 kB)
# Collecting astunparse>=1.6.0 (from tensorflow)
#   Downloading astunparse-1.6.3-py2.py3-none-any.whl (12 kB)
# Requirement already satisfied: flatbuffers>=23.5.26 in /home/dnth/anaconda3/envs/pytorch-edge/lib/python3.10/site-packages (from tensorflow) (23.5.26)
# Collecting gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 (from tensorflow)
#   Downloading gast-0.5.4-py3-none-any.whl (19 kB)
# Collecting google-pasta>=0.1.1 (from tensorflow)
#   Downloading google_pasta-0.2.0-py3-none-any.whl (57 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.5/57.5 kB 2.4 MB/s eta 0:00:00
# Collecting h5py>=2.9.0 (from tensorflow)
#   Obtaining dependency information for h5py>=2.9.0 from https://files.pythonhosted.org/packages/3b/d3/ecb4b3d2ec2c84132987e5f12ab1408f455bec1d90cd5bc408ebf37800f5/h5py-3.10.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata
#   Downloading h5py-3.10.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.5 kB)
# Collecting libclang>=13.0.0 (from tensorflow)
#   Obtaining dependency information for libclang>=13.0.0 from https://files.pythonhosted.org/packages/ea/df/55525e489c43f9dbb6c8ea27d8a567b3dcd18a22f3c45483055f5ca6611d/libclang-16.0.6-py2.py3-none-manylinux2010_x86_64.whl.metadata
#   Downloading libclang-16.0.6-py2.py3-none-manylinux2010_x86_64.whl.metadata (5.2 kB)
# Collecting ml-dtypes~=0.2.0 (from tensorflow)
#   Obtaining dependency information for ml-dtypes~=0.2.0 from https://files.pythonhosted.org/packages/d1/1d/d5cf76e5e40f69dbd273036e3172ae4a614577cb141673427b80cac948df/ml_dtypes-0.2.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata
#   Downloading ml_dtypes-0.2.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (20 kB)
# Requirement already satisfied: numpy<2.0.0,>=1.23.5 in /home/dnth/anaconda3/envs/pytorch-edge/lib/python3.10/site-packages (from tensorflow) (1.26.0)
# Collecting opt-einsum>=2.3.2 (from tensorflow)
#   Downloading opt_einsum-3.3.0-py3-none-any.whl (65 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.5/65.5 kB 3.8 MB/s eta 0:00:00
# Requirement already satisfied: packaging in /home/dnth/anaconda3/envs/pytorch-edge/lib/python3.10/site-packages (from tensorflow) (23.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /home/dnth/anaconda3/envs/pytorch-edge/lib/python3.10/site-packages (from tensorflow) (4.24.3)
# Requirement already satisfied: setuptools in /home/dnth/anaconda3/envs/pytorch-edge/lib/python3.10/site-packages (from tensorflow) (68.0.0)
# Requirement already satisfied: six>=1.12.0 in /home/dnth/anaconda3/envs/pytorch-edge/lib/python3.10/site-packages (from tensorflow) (1.16.0)
# Collecting termcolor>=1.1.0 (from tensorflow)
#   Downloading termcolor-2.3.0-py3-none-any.whl (6.9 kB)
# Requirement already satisfied: typing-extensions>=3.6.6 in /home/dnth/anaconda3/envs/pytorch-edge/lib/python3.10/site-packages (from tensorflow) (4.7.1)
# Collecting wrapt<1.15,>=1.11.0 (from tensorflow)
#   Downloading wrapt-1.14.1-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (77 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 3.3 MB/s eta 0:00:00
# Collecting tensorflow-io-gcs-filesystem>=0.23.1 (from tensorflow)
#   Obtaining dependency information for tensorflow-io-gcs-filesystem>=0.23.1 from https://files.pythonhosted.org/packages/88/99/8b507a009359fd55e411001acb64a1a8a4f81a26cb6e21c3b75c7fda4ae3/tensorflow_io_gcs_filesystem-0.34.0-cp310-cp310-manylinux_2_12_x86_64.manylinux2010_x86_64.whl.metadata
#   Downloading tensorflow_io_gcs_filesystem-0.34.0-cp310-cp310-manylinux_2_12_x86_64.manylinux2010_x86_64.whl.metadata (14 kB)
# Collecting grpcio<2.0,>=1.24.3 (from tensorflow)
#   Obtaining dependency information for grpcio<2.0,>=1.24.3 from https://files.pythonhosted.org/packages/d8/d0/0c42b56820f399f9bbcb4441fba1d4e52af3f11fa51c40c553fbd404aa1a/grpcio-1.59.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata
#   Downloading grpcio-1.59.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.0 kB)
# Collecting tensorboard<2.16,>=2.15 (from tensorflow)
#   Obtaining dependency information for tensorboard<2.16,>=2.15 from https://files.pythonhosted.org/packages/6e/0c/1059a6682cf2cc1fcc0d5327837b5672fe4f5574255fa5430d0a8ceb75e9/tensorboard-2.15.1-py3-none-any.whl.metadata
#   Downloading tensorboard-2.15.1-py3-none-any.whl.metadata (1.7 kB)
# Collecting tensorflow-estimator<2.16,>=2.15.0 (from tensorflow)
#   Obtaining dependency information for tensorflow-estimator<2.16,>=2.15.0 from https://files.pythonhosted.org/packages/b6/c8/2f823c8958d5342eafc6dd3e922f0cc4fcf8c2e0460284cc462dae3b60a0/tensorflow_estimator-2.15.0-py2.py3-none-any.whl.metadata
#   Downloading tensorflow_estimator-2.15.0-py2.py3-none-any.whl.metadata (1.3 kB)
# Collecting keras<2.16,>=2.15.0 (from tensorflow)
#   Obtaining dependency information for keras<2.16,>=2.15.0 from https://files.pythonhosted.org/packages/fc/a7/0d4490de967a67f68a538cc9cdb259bff971c4b5787f7765dc7c8f118f71/keras-2.15.0-py3-none-any.whl.metadata
#   Downloading keras-2.15.0-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /home/dnth/anaconda3/envs/pytorch-edge/lib/python3.10/site-packages (from astunparse>=1.6.0->tensorflow) (0.41.2)
# Collecting google-auth<3,>=1.6.3 (from tensorboard<2.16,>=2.15->tensorflow)
#   Obtaining dependency information for google-auth<3,>=1.6.3 from https://files.pythonhosted.org/packages/86/a7/75911c13a242735d5aeaca6a272da380335ff4ba5f26d6b2ae20ff682d13/google_auth-2.23.4-py2.py3-none-any.whl.metadata
#   Downloading google_auth-2.23.4-py2.py3-none-any.whl.metadata (4.7 kB)
# Collecting google-auth-oauthlib<2,>=0.5 (from tensorboard<2.16,>=2.15->tensorflow)
#   Obtaining dependency information for google-auth-oauthlib<2,>=0.5 from https://files.pythonhosted.org/packages/ce/33/a907b4b67245647746dde8d61e1643ef5d210c88e090d491efd89eff9f95/google_auth_oauthlib-1.1.0-py2.py3-none-any.whl.metadata
#   Downloading google_auth_oauthlib-1.1.0-py2.py3-none-any.whl.metadata (2.7 kB)
# Collecting markdown>=2.6.8 (from tensorboard<2.16,>=2.15->tensorflow)
#   Obtaining dependency information for markdown>=2.6.8 from https://files.pythonhosted.org/packages/70/58/2c5a654173937d9f540a4971c569b44dcd55e5424a484d954cdaeebcf79c/Markdown-3.5.1-py3-none-any.whl.metadata
#   Downloading Markdown-3.5.1-py3-none-any.whl.metadata (7.1 kB)
# Collecting protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 (from tensorflow)
#   Obtaining dependency information for protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 from https://files.pythonhosted.org/packages/01/cb/445b3e465abdb8042a41957dc8f60c54620dc7540dbcf9b458a921531ca2/protobuf-4.23.4-cp37-abi3-manylinux2014_x86_64.whl.metadata
#   Downloading protobuf-4.23.4-cp37-abi3-manylinux2014_x86_64.whl.metadata (540 bytes)
# Requirement already satisfied: requests<3,>=2.21.0 in /home/dnth/anaconda3/envs/pytorch-edge/lib/python3.10/site-packages (from tensorboard<2.16,>=2.15->tensorflow) (2.31.0)
# Collecting tensorboard-data-server<0.8.0,>=0.7.0 (from tensorboard<2.16,>=2.15->tensorflow)
#   Obtaining dependency information for tensorboard-data-server<0.8.0,>=0.7.0 from https://files.pythonhosted.org/packages/73/c6/825dab04195756cf8ff2e12698f22513b3db2f64925bdd41671bfb33aaa5/tensorboard_data_server-0.7.2-py3-none-manylinux_2_31_x86_64.whl.metadata
#   Downloading tensorboard_data_server-0.7.2-py3-none-manylinux_2_31_x86_64.whl.metadata (1.1 kB)
# Collecting werkzeug>=1.0.1 (from tensorboard<2.16,>=2.15->tensorflow)
#   Obtaining dependency information for werkzeug>=1.0.1 from https://files.pythonhosted.org/packages/c3/fc/254c3e9b5feb89ff5b9076a23218dafbc99c96ac5941e900b71206e6313b/werkzeug-3.0.1-py3-none-any.whl.metadata
#   Downloading werkzeug-3.0.1-py3-none-any.whl.metadata (4.1 kB)
# Collecting cachetools<6.0,>=2.0.0 (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow)
#   Obtaining dependency information for cachetools<6.0,>=2.0.0 from https://files.pythonhosted.org/packages/a2/91/2d843adb9fbd911e0da45fbf6f18ca89d07a087c3daa23e955584f90ebf4/cachetools-5.3.2-py3-none-any.whl.metadata
#   Downloading cachetools-5.3.2-py3-none-any.whl.metadata (5.2 kB)
# Collecting pyasn1-modules>=0.2.1 (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow)
#   Downloading pyasn1_modules-0.3.0-py2.py3-none-any.whl (181 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 181.3/181.3 kB 3.5 MB/s eta 0:00:00 MB/s eta 0:00:01
# Collecting rsa<5,>=3.1.4 (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow)
#   Downloading rsa-4.9-py3-none-any.whl (34 kB)
# Collecting requests-oauthlib>=0.7.0 (from google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow)
#   Downloading requests_oauthlib-1.3.1-py2.py3-none-any.whl (23 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/dnth/anaconda3/envs/pytorch-edge/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /home/dnth/anaconda3/envs/pytorch-edge/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/dnth/anaconda3/envs/pytorch-edge/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /home/dnth/anaconda3/envs/pytorch-edge/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow) (2023.7.22)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /home/dnth/.local/lib/python3.10/site-packages (from werkzeug>=1.0.1->tensorboard<2.16,>=2.15->tensorflow) (2.1.3)
# Collecting pyasn1<0.6.0,>=0.4.6 (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow)
#   Obtaining dependency information for pyasn1<0.6.0,>=0.4.6 from https://files.pythonhosted.org/packages/d1/75/4686d2872bf2fc0b37917cbc8bbf0dd3a5cdb0990799be1b9cbf1e1eb733/pyasn1-0.5.1-py2.py3-none-any.whl.metadata
#   Downloading pyasn1-0.5.1-py2.py3-none-any.whl.metadata (8.6 kB)
# Collecting oauthlib>=3.0.0 (from requests-oauthlib>=0.7.0->google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow)
#   Downloading oauthlib-3.2.2-py3-none-any.whl (151 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 151.7/151.7 kB 4.3 MB/s eta 0:00:004.4 MB/s eta 0:00:01
# Downloading tensorflow-2.15.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (475.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 475.2/475.2 MB 8.1 MB/s eta 0:00:00m eta 0:00:010:00:06m
# Downloading absl_py-2.0.0-py3-none-any.whl (130 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 130.2/130.2 kB 8.7 MB/s eta 0:00:00
# Downloading grpcio-1.59.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.3/5.3 MB 9.4 MB/s eta 0:00:009.4 MB/s eta 0:00:01
# Downloading h5py-3.10.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.8/4.8 MB 9.5 MB/s eta 0:00:00 MB/s eta 0:00:01:01m
# Downloading keras-2.15.0-py3-none-any.whl (1.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 10.5 MB/s eta 0:00:0031m10.6 MB/s eta 0:00:01
# Downloading libclang-16.0.6-py2.py3-none-manylinux2010_x86_64.whl (22.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 22.9/22.9 MB 8.1 MB/s eta 0:00:00m eta 0:00:010:00:01
# Downloading ml_dtypes-0.2.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 10.2 MB/s eta 0:00:0031m10.2 MB/s eta 0:00:01
# Downloading tensorboard-2.15.1-py3-none-any.whl (5.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 9.5 MB/s eta 0:00:00m eta 0:00:010:00:01m
# Downloading protobuf-4.23.4-cp37-abi3-manylinux2014_x86_64.whl (304 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 304.5/304.5 kB 9.0 MB/s eta 0:00:00
# Downloading tensorflow_estimator-2.15.0-py2.py3-none-any.whl (441 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 442.0/442.0 kB 9.1 MB/s eta 0:00:00 MB/s eta 0:00:01
# Downloading tensorflow_io_gcs_filesystem-0.34.0-cp310-cp310-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (2.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 8.9 MB/s eta 0:00:00 MB/s eta 0:00:01:01
# Downloading google_auth-2.23.4-py2.py3-none-any.whl (183 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 183.3/183.3 kB 11.1 MB/s eta 0:00:00
# Downloading google_auth_oauthlib-1.1.0-py2.py3-none-any.whl (19 kB)
# Downloading Markdown-3.5.1-py3-none-any.whl (102 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 102.2/102.2 kB 8.9 MB/s eta 0:00:00
# Downloading tensorboard_data_server-0.7.2-py3-none-manylinux_2_31_x86_64.whl (6.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.6/6.6 MB 9.0 MB/s eta 0:00:00 MB/s eta 0:00:01:01
# Downloading werkzeug-3.0.1-py3-none-any.whl (226 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 226.7/226.7 kB 7.8 MB/s eta 0:00:00
# Downloading cachetools-5.3.2-py3-none-any.whl (9.3 kB)
# Downloading pyasn1-0.5.1-py2.py3-none-any.whl (84 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.9/84.9 kB 6.2 MB/s eta 0:00:00
# Installing collected packages: libclang, wrapt, werkzeug, termcolor, tensorflow-io-gcs-filesystem, tensorflow-estimator, tensorboard-data-server, pyasn1, protobuf, opt-einsum, oauthlib, ml-dtypes, markdown, keras, h5py, grpcio, google-pasta, gast, cachetools, astunparse, absl-py, rsa, requests-oauthlib, pyasn1-modules, google-auth, google-auth-oauthlib, tensorboard, tensorflow
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 4.24.3
#     Uninstalling protobuf-4.24.3:
#       Successfully uninstalled protobuf-4.24.3
# Successfully installed absl-py-2.0.0 astunparse-1.6.3 cachetools-5.3.2 gast-0.5.4 google-auth-2.23.4 google-auth-oauthlib-1.1.0 google-pasta-0.2.0 grpcio-1.59.3 h5py-3.10.0 keras-2.15.0 libclang-16.0.6 markdown-3.5.1 ml-dtypes-0.2.0 oauthlib-3.2.2 opt-einsum-3.3.0 protobuf-4.23.4 pyasn1-0.5.1 pyasn1-modules-0.3.0 requests-oauthlib-1.3.1 rsa-4.9 tensorboard-2.15.1 tensorboard-data-server-0.7.2 tensorflow-2.15.0 tensorflow-estimator-2.15.0 tensorflow-io-gcs-filesystem-0.34.0 termcolor-2.3.0 werkzeug-3.0.1 wrapt-1.14.1

# %%
# !pip install onnx_graphsurgeon sng4onnx
# Out:
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# Requirement already satisfied: onnx_graphsurgeon in /home/dnth/anaconda3/envs/pytorch-edge/lib/python3.10/site-packages (0.3.27)
# Collecting sng4onnx
#   Downloading sng4onnx-1.0.1-py3-none-any.whl (5.8 kB)
# Requirement already satisfied: numpy in /home/dnth/anaconda3/envs/pytorch-edge/lib/python3.10/site-packages (from onnx_graphsurgeon) (1.26.0)
# Requirement already satisfied: onnx in /home/dnth/anaconda3/envs/pytorch-edge/lib/python3.10/site-packages (from onnx_graphsurgeon) (1.14.1)
# Requirement already satisfied: protobuf>=3.20.2 in /home/dnth/anaconda3/envs/pytorch-edge/lib/python3.10/site-packages (from onnx->onnx_graphsurgeon) (4.23.4)
# Requirement already satisfied: typing-extensions>=3.6.2.1 in /home/dnth/anaconda3/envs/pytorch-edge/lib/python3.10/site-packages (from onnx->onnx_graphsurgeon) (4.7.1)
# Installing collected packages: sng4onnx
# Successfully installed sng4onnx-1.0.1

# %%
# !onnx2tf -i convnextv2_base.fcmae_ft_in22k_in1k.onnx
# Out:
# Model optimizing started ============================================================
# Simplifying...
# Finish! Here is the difference:
# ┏━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━┓
# ┃                   ┃ Original Model ┃ Simplified Model ┃
# ┡━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━┩
# │ Abs               │ 36             │ 36               │
# │ Add               │ 334            │ 334              │
# │ Constant          │ 750            │ 386              │
# │ Conv              │ 40             │ 40               │
# │ Div               │ 113            │ 113              │
# │ Erf               │ 36             │ 36               │
# │ Flatten           │ 1              │ 1                │
# │ Gemm              │ 1              │ 1                │
# │ GlobalAveragePool │ 1              │ 1                │
# │ MatMul            │ 72             │ 72               │
# │ Mul               │ 221            │ 185              │
# │ Pow               │ 113            │ 113              │
# │ ReduceMean        │ 118            │ 118              │
# │ ReduceSum         │ 36             │ 36               │
# │ Sqrt              │ 41             │ 41               │
# │ Sub               │ 41             │ 41               │
# │ Transpose         │ 82             │ 82               │
# │ Model Size        │ 338.8MiB       │ 338.8MiB         │
# └───────────────────┴────────────────┴──────────────────┘
#
# Simplifying...
# Finish! Here is the difference:
# ┏━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━┓
# ┃                   ┃ Original Model ┃ Simplified Model ┃
# ┡━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━┩
# │ Abs               │ 36             │ 36               │
# │ Add               │ 334            │ 334              │
# │ Constant          │ 386            │ 386              │
# │ Conv              │ 40             │ 40               │
# │ Div               │ 113            │ 113              │
# │ Erf               │ 36             │ 36               │
# │ Flatten           │ 1              │ 1                │
# │ Gemm              │ 1              │ 1                │
# │ GlobalAveragePool │ 1              │ 1                │
# │ MatMul            │ 72             │ 72               │
# │ Mul               │ 185            │ 185              │
# │ Pow               │ 113            │ 113              │
# │ ReduceMean        │ 118            │ 118              │
# │ ReduceSum         │ 36             │ 36               │
# │ Sqrt              │ 41             │ 41               │
# │ Sub               │ 41             │ 41               │
# │ Transpose         │ 82             │ 82               │
# │ Model Size        │ 338.8MiB       │ 338.8MiB         │
# └───────────────────┴────────────────┴──────────────────┘
#
# Simplifying...
# Finish! Here is the difference:
# ┏━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━┓
# ┃                   ┃ Original Model ┃ Simplified Model ┃
# ┡━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━┩
# │ Abs               │ 36             │ 36               │
# │ Add               │ 334            │ 334              │
# │ Constant          │ 386            │ 386              │
# │ Conv              │ 40             │ 40               │
# │ Div               │ 113            │ 113              │
# │ Erf               │ 36             │ 36               │
# │ Flatten           │ 1              │ 1                │
# │ Gemm              │ 1              │ 1                │
# │ GlobalAveragePool │ 1              │ 1                │
# │ MatMul            │ 72             │ 72               │
# │ Mul               │ 185            │ 185              │
# │ Pow               │ 113            │ 113              │
# │ ReduceMean        │ 118            │ 118              │
# │ ReduceSum         │ 36             │ 36               │
# │ Sqrt              │ 41             │ 41               │
# │ Sub               │ 41             │ 41               │
# │ Transpose         │ 82             │ 82               │
# │ Model Size        │ 338.8MiB       │ 338.8MiB         │
# └───────────────────┴────────────────┴──────────────────┘
#
# Model optimizing complete!
#
# Automatic generation of each OP name started ========================================
# Automatic generation of each OP name complete!
#
# Model loaded ========================================================================
#
# Model conversion started ============================================================
# INFO: input_op_name: input shape: ['batch_size', 3, 224, 224] dtype: float32
#
# INFO: 2 / 1251
# INFO: onnx_op_type: Conv onnx_op_name: /stem/stem.0/Conv
# INFO:  input_name.1: input shape: ['batch_size', 3, 224, 224] dtype: float32
# INFO:  input_name.2: stem.0.weight shape: [128, 3, 4, 4] dtype: float32
# INFO:  input_name.3: stem.0.bias shape: [128] dtype: float32
# INFO:  output_name.1: /stem/stem.0/Conv_output_0 shape: ['batch_size', 128, 56, 56] dtype: float32
# INFO: tf_op_type: convolution_v2
# INFO:  input.1.input: name: input shape: (None, 224, 224, 3) dtype: <dtype: 'float32'>
# INFO:  input.2.weights: shape: (4, 4, 3, 128) dtype: <dtype: 'float32'>
# INFO:  input.3.bias: shape: (128,) dtype: <dtype: 'float32'>
# INFO:  input.4.strides: val: [4, 4]
# INFO:  input.5.dilations: val: [1, 1]
# INFO:  input.6.padding: val: VALID
# INFO:  input.7.group: val: 1
# INFO:  output.1.output: name: tf.math.add/Add:0 shape: (None, 56, 56, 128) dtype: <dtype: 'float32'>
#
# INFO: 3 / 1251
# INFO: onnx_op_type: Transpose onnx_op_name: /stem/stem.1/Transpose
# INFO:  input_name.1: /stem/stem.0/Conv_output_0 shape: ['batch_size', 128, 56, 56] dtype: float32
# INFO:  output_name.1: /stem/stem.1/Transpose_output_0 shape: ['batch_size', 56, 56, 128] dtype: float32
# INFO: tf_op_type: transpose_v2
# INFO:  input.1.a: name: tf.math.add/Add:0 shape: (None, 56, 56, 128) dtype: <dtype: 'float32'>
# INFO:  input.2.perm: val: [0, 1, 2, 3]
# INFO:  output.1.output: name: tf.math.add/Add:0 shape: (None, 56, 56, 128) dtype: <dtype: 'float32'>
#
# INFO: 4 / 1251
# INFO: onnx_op_type: ReduceMean onnx_op_name: /stem/stem.1/ReduceMean
# INFO:  input_name.1: /stem/stem.1/Transpose_output_0 shape: ['batch_size', 56, 56, 128] dtype: float32
# INFO:  output_name.1: /stem/stem.1/ReduceMean_output_0 shape: ['batch_size', 56, 56, 1] dtype: float32
# INFO: tf_op_type: reduce_mean
# INFO:  input.1.axis0: val: 3
# INFO:  input.2.input_tensor: name: tf.math.add/Add:0 shape: (None, 56, 56, 128) dtype: <dtype: 'float32'>
# INFO:  input.3.keepdims: val: True
# INFO:  output.1.output: name: tf.math.reduce_mean/Mean:0 shape: (None, 56, 56, 1) dtype: <dtype: 'float32'>
#
# INFO: 5 / 1251
# INFO: onnx_op_type: Sub onnx_op_name: /stem/stem.1/Sub
# INFO:  input_name.1: /stem/stem.1/Transpose_output_0 shape: ['batch_size', 56, 56, 128] dtype: float32
# INFO:  input_name.2: /stem/stem.1/ReduceMean_output_0 shape: ['batch_size', 56, 56, 1] dtype: float32
# INFO:  output_name.1: /stem/stem.1/Sub_output_0 shape: ['batch_size', 56, 56, 128] dtype: float32
# INFO: tf_op_type: subtract
# INFO:  input.1.x: name: tf.compat.v1.transpose/transpose:0 shape: (None, 56, 56, 128) dtype: <dtype: 'float32'>
# INFO:  input.2.y: name: tf.compat.v1.transpose_1/transpose:0 shape: (None, 56, 56, 1) dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.math.subtract_1/Sub:0 shape: (None, 56, 56, 128) dtype: <dtype: 'float32'>
#
# INFO: 6 / 1251
# INFO: onnx_op_type: Pow onnx_op_name: /stem/stem.1/Pow
# INFO:  input_name.1: /stem/stem.1/Sub_output_0 shape: ['batch_size', 56, 56, 128] dtype: float32
# INFO:  input_name.2: /stem/stem.1/Constant_output_0 shape: [] dtype: float32
# INFO:  output_name.1: /stem/stem.1/Pow_output_0 shape: ['batch_size', 56, 56, 128] dtype: float32
# INFO: tf_op_type: pow
# INFO:  input.1.x: name: tf.math.subtract_1/Sub:0 shape: (None, 56, 56, 128) dtype: <dtype: 'float32'>
# INFO:  input.2.y: shape: () dtype: float32
# INFO:  output.1.output: name: tf.math.multiply_1/Mul:0 shape: (None, 56, 56, 128) dtype: <dtype: 'float32'>
#
# INFO: 7 / 1251
# INFO: onnx_op_type: ReduceMean onnx_op_name: /stem/stem.1/ReduceMean_1
# INFO:  input_name.1: /stem/stem.1/Pow_output_0 shape: ['batch_size', 56, 56, 128] dtype: float32
# INFO:  output_name.1: /stem/stem.1/ReduceMean_1_output_0 shape: ['batch_size', 56, 56, 1] dtype: float32
# INFO: tf_op_type: reduce_mean
# INFO:  input.1.axis0: val: 3
# INFO:  input.2.input_tensor: name: tf.math.multiply_1/Mul:0 shape: (None, 56, 56, 128) dtype: <dtype: 'float32'>
# INFO:  input.3.keepdims: val: True
# INFO:  output.1.output: name: tf.math.reduce_mean_1/Mean:0 shape: (None, 56, 56, 1) dtype: <dtype: 'float32'>
#
# INFO: 8 / 1251
# INFO: onnx_op_type: Add onnx_op_name: /stem/stem.1/Add
# INFO:  input_name.1: /stem/stem.1/ReduceMean_1_output_0 shape: ['batch_size', 56, 56, 1] dtype: float32
# INFO:  input_name.2: /stem/stem.1/Constant_1_output_0 shape: [] dtype: float32
# INFO:  output_name.1: /stem/stem.1/Add_output_0 shape: ['batch_size', 56, 56, 1] dtype: float32
# INFO: tf_op_type: add
# INFO:  input.1.x: name: tf.compat.v1.transpose_2/transpose:0 shape: (None, 56, 56, 1) dtype: <dtype: 'float32'>
# INFO:  input.2.y: shape: () dtype: float32
# INFO:  output.1.output: name: tf.math.add_2/Add:0 shape: (None, 56, 56, 1) dtype: <dtype: 'float32'>
#
# INFO: 9 / 1251
# INFO: onnx_op_type: Sqrt onnx_op_name: /stem/stem.1/Sqrt
# INFO:  input_name.1: /stem/stem.1/Add_output_0 shape: ['batch_size', 56, 56, 1] dtype: float32
# INFO:  output_name.1: /stem/stem.1/Sqrt_output_0 shape: ['batch_size', 56, 56, 1] dtype: float32
# INFO: tf_op_type: sqrt
# INFO:  input.1.x: name: tf.math.add_2/Add:0 shape: (None, 56, 56, 1) dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.math.sqrt/Sqrt:0 shape: (None, 56, 56, 1) dtype: <dtype: 'float32'>
#
# INFO: 10 / 1251
# INFO: onnx_op_type: Div onnx_op_name: /stem/stem.1/Div
# INFO:  input_name.1: /stem/stem.1/Sub_output_0 shape: ['batch_size', 56, 56, 128] dtype: float32
# INFO:  input_name.2: /stem/stem.1/Sqrt_output_0 shape: ['batch_size', 56, 56, 1] dtype: float32
# INFO:  output_name.1: /stem/stem.1/Div_output_0 shape: ['batch_size', 56, 56, 128] dtype: float32
# INFO: tf_op_type: divide
# INFO:  input.1.x: name: tf.compat.v1.transpose_3/transpose:0 shape: (None, 56, 56, 128) dtype: <dtype: 'float32'>
# INFO:  input.2.y: name: tf.compat.v1.transpose_4/transpose:0 shape: (None, 56, 56, 1) dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.math.divide/truediv:0 shape: (None, 56, 56, 128) dtype: <dtype: 'float32'>
#
# INFO: 11 / 1251
# INFO: onnx_op_type: Mul onnx_op_name: /stem/stem.1/Mul
# INFO:  input_name.1: /stem/stem.1/Div_output_0 shape: ['batch_size', 56, 56, 128] dtype: float32
# INFO:  input_name.2: stem.1.weight shape: [128] dtype: float32
# INFO:  output_name.1: /stem/stem.1/Mul_output_0 shape: ['batch_size', 56, 56, 128] dtype: float32
# INFO: tf_op_type: multiply
# INFO:  input.1.x: name: tf.compat.v1.transpose_5/transpose:0 shape: (None, 56, 56, 128) dtype: <dtype: 'float32'>
# INFO:  input.2.y: shape: (1, 1, 1, 128) dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.math.multiply_4/Mul:0 shape: (None, 56, 56, 128) dtype: <dtype: 'float32'>
#
# INFO: 12 / 1251
# INFO: onnx_op_type: Add onnx_op_name: /stem/stem.1/Add_1
# INFO:  input_name.1: /stem/stem.1/Mul_output_0 shape: ['batch_size', 56, 56, 128] dtype: float32
# INFO:  input_name.2: stem.1.bias shape: [128] dtype: float32
# INFO:  output_name.1: /stem/stem.1/Add_1_output_0 shape: ['batch_size', 56, 56, 128] dtype: float32
# INFO: tf_op_type: add
# INFO:  input.1.x: name: tf.compat.v1.transpose_6/transpose:0 shape: (None, 56, 56, 128) dtype: <dtype: 'float32'>
# INFO:  input.2.y: shape: (1, 1, 1, 128) dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.math.add_4/Add:0 shape: (None, 56, 56, 128) dtype: <dtype: 'float32'>
#
# INFO: 13 / 1251
# INFO: onnx_op_type: Transpose onnx_op_name: /stem/stem.1/Transpose_1
# INFO:  input_name.1: /stem/stem.1/Add_1_output_0 shape: ['batch_size', 56, 56, 128] dtype: float32
# INFO:  output_name.1: /stem/stem.1/Transpose_1_output_0 shape: ['batch_size', 128, 56, 56] dtype: float32
# INFO: tf_op_type: transpose_v2
# INFO:  input.1.a: name: tf.math.add_4/Add:0 shape: (None, 56, 56, 128) dtype: <dtype: 'float32'>
# INFO:  input.2.perm: val: [0, 3, 1, 2]
# INFO:  output.1.output: name: tf.compat.v1.transpose_7/transpose:0 shape: (None, 128, 56, 56) dtype: <dtype: 'float32'>
#
# INFO: 14 / 1251
# INFO: onnx_op_type: Conv onnx_op_name: /stages/stages.0/blocks/blocks.0/conv_dw/Conv
# INFO:  input_name.1: /stem/stem.1/Transpose_1_output_0 shape: ['batch_size', 128, 56, 56] dtype: float32
# INFO:  input_name.2: stages.0.blocks.0.conv_dw.weight shape: [128, 1, 7, 7] dtype: float32
# INFO:  input_name.3: stages.0.blocks.0.conv_dw.bias shape: [128] dtype: float32
# INFO:  output_name.1: /stages/stages.0/blocks/blocks.0/conv_dw/Conv_output_0 shape: ['batch_size', 128, 56, 56] dtype: float32
# WARNING: This model contains GroupConvolution and is automatically optimized for TFLite, but is not output because saved_model does not support GroupConvolution. If saved_model is needed, specify --disable_group_convolution to retransform the model.
# INFO: tf_op_type: GroupedConvolution2D
# INFO:  input.1.input: name: tf.compat.v1.transpose_8/transpose:0 shape: (None, 56, 56, 128) dtype: <dtype: 'float32'>
# INFO:  input.2.weights: shape: (7, 7, 1, 128) dtype: <dtype: 'float32'>
# INFO:  input.3.bias: shape: (128,) dtype: <dtype: 'float32'>
# INFO:  input.4.strides: val: [1, 1]
# INFO:  input.5.dilations: val: [1, 1]
# INFO:  input.6.padding: val: SAME
# INFO:  input.7.group: val: 128
# INFO:  output.1.output: name: tf.math.add_5/Add:0 shape: (None, 56, 56, 128) dtype: <dtype: 'float32'>
#
# INFO: 15 / 1251
# INFO: onnx_op_type: Transpose onnx_op_name: /stages/stages.0/blocks/blocks.0/Transpose
# INFO:  input_name.1: /stages/stages.0/blocks/blocks.0/conv_dw/Conv_output_0 shape: ['batch_size', 128, 56, 56] dtype: float32
# INFO:  output_name.1: /stages/stages.0/blocks/blocks.0/Transpose_output_0 shape: ['batch_size', 56, 56, 128] dtype: float32
# INFO: tf_op_type: transpose_v2
# INFO:  input.1.a: name: tf.math.add_5/Add:0 shape: (None, 56, 56, 128) dtype: <dtype: 'float32'>
# INFO:  input.2.perm: val: [0, 1, 2, 3]
# INFO:  output.1.output: name: tf.math.add_5/Add:0 shape: (None, 56, 56, 128) dtype: <dtype: 'float32'>
#
# INFO: 16 / 1251
# INFO: onnx_op_type: ReduceMean onnx_op_name: /stages/stages.0/blocks/blocks.0/norm/ReduceMean
# INFO:  input_name.1: /stages/stages.0/blocks/blocks.0/Transpose_output_0 shape: ['batch_size', 56, 56, 128] dtype: float32
# INFO:  output_name.1: /stages/stages.0/blocks/blocks.0/norm/ReduceMean_output_0 shape: ['batch_size', 56, 56, 1] dtype: float32
# INFO: tf_op_type: reduce_mean
# INFO:  input.1.axis0: val: 3
# INFO:  input.2.input_tensor: name: tf.math.add_5/Add:0 shape: (None, 56, 56, 128) dtype: <dtype: 'float32'>
# INFO:  input.3.keepdims: val: True
# INFO:  output.1.output: name: tf.math.reduce_mean_2/Mean:0 shape: (None, 56, 56, 1) dtype: <dtype: 'float32'>
#
# INFO: 17 / 1251
# INFO: onnx_op_type: Sub onnx_op_name: /stages/stages.0/blocks/blocks.0/norm/Sub
# INFO:  input_name.1: /stages/stages.0/blocks/blocks.0/Transpose_output_0 shape: ['batch_size', 56, 56, 128] dtype: float32
# INFO:  input_name.2: /stages/stages.0/blocks/blocks.0/norm/ReduceMean_output_0 shape: ['batch_size', 56, 56, 1] dtype: float32
# INFO:  output_name.1: /stages/stages.0/blocks/blocks.0/norm/Sub_output_0 shape: ['batch_size', 56, 56, 128] dtype: float32
# INFO: tf_op_type: subtract
# INFO:  input.1.x: name: tf.compat.v1.transpose_9/transpose:0 shape: (None, 56, 56, 128) dtype: <dtype: 'float32'>
# INFO:  input.2.y: name: tf.compat.v1.transpose_10/transpose:0 shape: (None, 56, 56, 1) dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.math.subtract_3/Sub:0 shape: (None, 56, 56, 128) dtype: <dtype: 'float32'>
#
# INFO: 18 / 1251
# INFO: onnx_op_type: Pow onnx_op_name: /stages/stages.0/blocks/blocks.0/norm/Pow
# INFO:  input_name.1: /stages/stages.0/blocks/blocks.0/norm/Sub_output_0 shape: ['batch_size', 56, 56, 128] dtype: float32
# INFO:  input_name.2: /stem/stem.1/Constant_output_0 shape: () dtype: float32
# INFO:  output_name.1: /stages/stages.0/blocks/blocks.0/norm/Pow_output_0 shape: ['batch_size', 56, 56, 128] dtype: float32
# INFO: tf_op_type: pow
# INFO:  input.1.x: name: tf.math.subtract_3/Sub:0 shape: (None, 56, 56, 128) dtype: <dtype: 'float32'>
# INFO:  input.2.y: shape: () dtype: float32
# INFO:  output.1.output: name: tf.math.multiply_6/Mul:0 shape: (None, 56, 56, 128) dtype: <dtype: 'float32'>
#
# INFO: 19 / 1251
# INFO: onnx_op_type: ReduceMean onnx_op_name: /stages/stages.0/blocks/blocks.0/norm/ReduceMean_1
# INFO:  input_name.1: /stages/stages.0/blocks/blocks.0/norm/Pow_output_0 shape: ['batch_size', 56, 56, 128] dtype: float32
# INFO:  output_name.1: /stages/stages.0/blocks/blocks.0/norm/ReduceMean_1_output_0 shape: ['batch_size', 56, 56, 1] dtype: float32
# INFO: tf_op_type: reduce_mean
# INFO:  input.1.axis0: val: 3
# INFO:  input.2.input_tensor: name: tf.math.multiply_6/Mul:0 shape: (None, 56, 56, 128) dtype: <dtype: 'float32'>
# INFO:  input.3.keepdims: val: True
# INFO:  output.1.output: name: tf.math.reduce_mean_3/Mean:0 shape: (None, 56, 56, 1) dtype: <dtype: 'float32'>
#
# INFO: 20 / 1251
# INFO: onnx_op_type: Add onnx_op_name: /stages/stages.0/blocks/blocks.0/norm/Add
# INFO:  input_name.1: /stages/stages.0/blocks/blocks.0/norm/ReduceMean_1_output_0 shape: ['batch_size', 56, 56, 1] dtype: float32
# INFO:  input_name.2: /stem/stem.1/Constant_1_output_0 shape: () dtype: float32
# INFO:  output_name.1: /stages/stages.0/blocks/blocks.0/norm/Add_output_0 shape: ['batch_size', 56, 56, 1] dtype: float32
# INFO: tf_op_type: add
# INFO:  input.1.x: name: tf.compat.v1.transpose_11/transpose:0 shape: (None, 56, 56, 1) dtype: <dtype: 'float32'>
# INFO:  input.2.y: shape: () dtype: float32
# INFO:  output.1.output: name: tf.math.add_7/Add:0 shape: (None, 56, 56, 1) dtype: <dtype: 'float32'>
#
# INFO: 21 / 1251
# INFO: onnx_op_type: Sqrt onnx_op_name: /stages/stages.0/blocks/blocks.0/norm/Sqrt
# INFO:  input_name.1: /stages/stages.0/blocks/blocks.0/norm/Add_output_0 shape: ['batch_size', 56, 56, 1] dtype: float32
# INFO:  output_name.1: /stages/stages.0/blocks/blocks.0/norm/Sqrt_output_0 shape: ['batch_size', 56, 56, 1] dtype: float32
# INFO: tf_op_type: sqrt
# INFO:  input.1.x: name: tf.math.add_7/Add:0 shape: (None, 56, 56, 1) dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.math.sqrt_1/Sqrt:0 shape: (None, 56, 56, 1) dtype: <dtype: 'float32'>
#
# INFO: 22 / 1251
# INFO: onnx_op_type: Div onnx_op_name: /stages/stages.0/blocks/blocks.0/norm/Div
# INFO:  input_name.1: /stages/stages.0/blocks/blocks.0/norm/Sub_output_0 shape: ['batch_size', 56, 56, 128] dtype: float32
# INFO:  input_name.2: /stages/stages.0/blocks/blocks.0/norm/Sqrt_output_0 shape: ['batch_size', 56, 56, 1] dtype: float32
# INFO:  output_name.1: /stages/stages.0/blocks/blocks.0/norm/Div_output_0 shape: ['batch_size', 56, 56, 128] dtype: float32
# INFO: tf_op_type: divide
# INFO:  input.1.x: name: tf.compat.v1.transpose_12/transpose:0 shape: (None, 56, 56, 128) dtype: <dtype: 'float32'>
# INFO:  input.2.y: name: tf.compat.v1.transpose_13/transpose:0 shape: (None, 56, 56, 1) dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.math.divide_1/truediv:0 shape: (None, 56, 56, 128) dtype: <dtype: 'float32'>
#
# INFO: 23 / 1251
# INFO: onnx_op_type: Mul onnx_op_name: /stages/stages.0/blocks/blocks.0/norm/Mul
# INFO:  input_name.1: /stages/stages.0/blocks/blocks.0/norm/Div_output_0 shape: ['batch_size', 56, 56, 128] dtype: float32
# INFO:  input_name.2: stages.0.blocks.0.norm.weight shape: [128] dtype: float32
# INFO:  output_name.1: /stages/stages.0/blocks/blocks.0/norm/Mul_output_0 shape: ['batch_size', 56, 56, 128] dtype: float32
# INFO: tf_op_type: multiply
# INFO:  input.1.x: name: tf.compat.v1.transpose_14/transpose:0 shape: (None, 56, 56, 128) dtype: <dtype: 'float32'>
# INFO:  input.2.y: shape: (1, 1, 1, 128) dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.math.multiply_9/Mul:0 shape: (None, 56, 56, 128) dtype: <dtype: 'float32'>
#
# INFO: 24 / 1251
# INFO: onnx_op_type: Add onnx_op_name: /stages/stages.0/blocks/blocks.0/norm/Add_1
# INFO:  input_name.1: /stages/stages.0/blocks/blocks.0/norm/Mul_output_0 shape: ['batch_size', 56, 56, 128] dtype: float32
# INFO:  input_name.2: stages.0.blocks.0.norm.bias shape: [128] dtype: float32
# INFO:  output_name.1: /stages/stages.0/blocks/blocks.0/norm/Add_1_output_0 shape: ['batch_size', 56, 56, 128] dtype: float32
# INFO: tf_op_type: add
# INFO:  input.1.x: name: tf.compat.v1.transpose_15/transpose:0 shape: (None, 56, 56, 128) dtype: <dtype: 'float32'>
# INFO:  input.2.y: shape: (1, 1, 1, 128) dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.math.add_9/Add:0 shape: (None, 56, 56, 128) dtype: <dtype: 'float32'>
#
# INFO: 25 / 1251
# INFO: onnx_op_type: MatMul onnx_op_name: /stages/stages.0/blocks/blocks.0/mlp/fc1/MatMul
# INFO:  input_name.1: /stages/stages.0/blocks/blocks.0/norm/Add_1_output_0 shape: ['batch_size', 56, 56, 128] dtype: float32
# INFO:  input_name.2: onnx::MatMul_2325 shape: [128, 512] dtype: float32
# INFO:  output_name.1: /stages/stages.0/blocks/blocks.0/mlp/fc1/MatMul_output_0 shape: ['batch_size', 56, 56, 512] dtype: float32
# INFO: tf_op_type: matmul
# INFO:  input.1.a: name: tf.math.add_9/Add:0 shape: (None, 56, 56, 128) dtype: <dtype: 'float32'>
# INFO:  input.2.b: shape: (128, 512) dtype: float32
# INFO:  input.3.output_type: name: float32 shape: ()
# INFO:  output.1.output: name: tf.compat.v1.transpose_16/transpose:0 shape: (None, 56, 56, 512) dtype: <dtype: 'float32'>
#
# INFO: 26 / 1251
# INFO: onnx_op_type: Add onnx_op_name: /stages/stages.0/blocks/blocks.0/mlp/fc1/Add
# INFO:  input_name.1: stages.0.blocks.0.mlp.fc1.bias shape: [512] dtype: float32
# INFO:  input_name.2: /stages/stages.0/blocks/blocks.0/mlp/fc1/MatMul_output_0 shape: ['batch_size', 56, 56, 512] dtype: float32
# INFO:  output_name.1: /stages/stages.0/blocks/blocks.0/mlp/fc1/Add_output_0 shape: ['batch_size', 56, 56, 512] dtype: float32
# INFO: tf_op_type: add
# INFO:  input.1.x: name: tf.compat.v1.transpose_17/transpose:0 shape: (None, 56, 56, 512) dtype: <dtype: 'float32'>
# INFO:  input.2.y: shape: (512,) dtype: float32
# INFO:  output.1.output: name: tf.math.add_11/Add:0 shape: (None, 56, 56, 512) dtype: <dtype: 'float32'>
#
# INFO: 27 / 1251
# INFO: onnx_op_type: Div onnx_op_name: /stages/stages.0/blocks/blocks.0/mlp/act/Div
# INFO:  input_name.1: /stages/stages.0/blocks/blocks.0/mlp/fc1/Add_output_0 shape: ['batch_size', 56, 56, 512] dtype: float32
# INFO:  input_name.2: /stages/stages.0/blocks/blocks.0/mlp/act/Constant_output_0 shape: [] dtype: float32
# INFO:  output_name.1: /stages/stages.0/blocks/blocks.0/mlp/act/Div_output_0 shape: ['batch_size', 56, 56, 512] dtype: float32
# INFO: tf_op_type: divide
# INFO:  input.1.x: name: tf.compat.v1.transpose_18/transpose:0 shape: (None, 56, 56, 512) dtype: <dtype: 'float32'>
# INFO:  input.2.y: shape: () dtype: float32
# INFO:  output.1.output: name: tf.math.divide_2/truediv:0 shape: (None, 56, 56, 512) dtype: <dtype: 'float32'>
#
# INFO: 28 / 1251
# INFO: onnx_op_type: Erf onnx_op_name: /stages/stages.0/blocks/blocks.0/mlp/act/Erf
# INFO:  input_name.1: /stages/stages.0/blocks/blocks.0/mlp/act/Div_output_0 shape: ['batch_size', 56, 56, 512] dtype: float32
# INFO:  output_name.1: /stages/stages.0/blocks/blocks.0/mlp/act/Erf_output_0 shape: ['batch_size', 56, 56, 512] dtype: float32
# INFO: tf_op_type: erf
# INFO:  input.1.x: name: tf.math.divide_2/truediv:0 shape: (None, 56, 56, 512) dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.math.erf/Erf:0 shape: (None, 56, 56, 512) dtype: <dtype: 'float32'>
#
# INFO: 29 / 1251
# INFO: onnx_op_type: Add onnx_op_name: /stages/stages.0/blocks/blocks.0/mlp/act/Add
# INFO:  input_name.1: /stages/stages.0/blocks/blocks.0/mlp/act/Erf_output_0 shape: ['batch_size', 56, 56, 512] dtype: float32
# INFO:  input_name.2: /stages/stages.0/blocks/blocks.0/mlp/act/Constant_1_output_0 shape: [] dtype: float32
# INFO:  output_name.1: /stages/stages.0/blocks/blocks.0/mlp/act/Add_output_0 shape: ['batch_size', 56, 56, 512] dtype: float32
# INFO: tf_op_type: add
# INFO:  input.1.x: name: tf.compat.v1.transpose_19/transpose:0 shape: (None, 56, 56, 512) dtype: <dtype: 'float32'>
# INFO:  input.2.y: shape: () dtype: float32
# INFO:  output.1.output: name: tf.math.add_13/Add:0 shape: (None, 56, 56, 512) dtype: <dtype: 'float32'>
#
# INFO: 30 / 1251
# INFO: onnx_op_type: Mul onnx_op_name: /stages/stages.0/blocks/blocks.0/mlp/act/Mul
# INFO:  input_name.1: /stages/stages.0/blocks/blocks.0/mlp/fc1/Add_output_0 shape: ['batch_size', 56, 56, 512] dtype: float32
# INFO:  input_name.2: /stages/stages.0/blocks/blocks.0/mlp/act/Add_output_0 shape: ['batch_size', 56, 56, 512] dtype: float32
# INFO:  output_name.1: /stages/stages.0/blocks/blocks.0/mlp/act/Mul_output_0 shape: ['batch_size', 56, 56, 512] dtype: float32
# INFO: tf_op_type: multiply
# INFO:  input.1.x: name: tf.compat.v1.transpose_20/transpose:0 shape: (None, 56, 56, 512) dtype: <dtype: 'float32'>
# INFO:  input.2.y: name: tf.compat.v1.transpose_21/transpose:0 shape: (None, 56, 56, 512) dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.math.multiply_12/Mul:0 shape: (None, 56, 56, 512) dtype: <dtype: 'float32'>
#
# INFO: 31 / 1251
# INFO: onnx_op_type: Mul onnx_op_name: /stages/stages.0/blocks/blocks.0/mlp/act/Mul_1
# INFO:  input_name.1: /stages/stages.0/blocks/blocks.0/mlp/act/Mul_output_0 shape: ['batch_size', 56, 56, 512] dtype: float32
# INFO:  input_name.2: /stages/stages.0/blocks/blocks.0/mlp/act/Constant_2_output_0 shape: [] dtype: float32
# INFO:  output_name.1: /stages/stages.0/blocks/blocks.0/mlp/act/Mul_1_output_0 shape: ['batch_size', 56, 56, 512] dtype: float32
# INFO: tf_op_type: multiply
# INFO:  input.1.x: name: tf.compat.v1.transpose_22/transpose:0 shape: (None, 56, 56, 512) dtype: <dtype: 'float32'>
# INFO:  input.2.y: shape: () dtype: float32
# INFO:  output.1.output: name: tf.math.multiply_14/Mul:0 shape: (None, 56, 56, 512) dtype: <dtype: 'float32'>
#
# INFO: 32 / 1251
# INFO: onnx_op_type: Abs onnx_op_name: /stages/stages.0/blocks/blocks.0/mlp/grn/Abs
# INFO:  input_name.1: /stages/stages.0/blocks/blocks.0/mlp/act/Mul_1_output_0 shape: ['batch_size', 56, 56, 512] dtype: float32
# INFO:  output_name.1: /stages/stages.0/blocks/blocks.0/mlp/grn/Abs_output_0 shape: ['batch_size', 56, 56, 512] dtype: float32
# INFO: tf_op_type: abs
# INFO:  input.1.x: name: tf.math.multiply_14/Mul:0 shape: (None, 56, 56, 512) dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.math.abs/Abs:0 shape: (None, 56, 56, 512) dtype: <dtype: 'float32'>
#
# INFO: 33 / 1251
# INFO: onnx_op_type: Pow onnx_op_name: /stages/stages.0/blocks/blocks.0/mlp/grn/Pow
# INFO:  input_name.1: /stages/stages.0/blocks/blocks.0/mlp/grn/Abs_output_0 shape: ['batch_size', 56, 56, 512] dtype: float32
# INFO:  input_name.2: /stem/stem.1/Constant_output_0 shape: () dtype: float32
# INFO:  output_name.1: /stages/stages.0/blocks/blocks.0/mlp/grn/Pow_output_0 shape: ['batch_size', 56, 56, 512] dtype: float32
# INFO: tf_op_type: pow
# INFO:  input.1.x: name: tf.math.abs/Abs:0 shape: (None, 56, 56, 512) dtype: <dtype: 'float32'>
# INFO:  input.2.y: shape: () dtype: float32
# INFO:  output.1.output: name: tf.math.multiply_15/Mul:0 shape: (None, 56, 56, 512) dtype: <dtype: 'float32'>
#
# INFO: 34 / 1251
# INFO: onnx_op_type: ReduceSum onnx_op_name: /stages/stages.0/blocks/blocks.0/mlp/grn/ReduceSum
# INFO:  input_name.1: /stages/stages.0/blocks/blocks.0/mlp/grn/Pow_output_0 shape: ['batch_size', 56, 56, 512] dtype: float32
# INFO:  input_name.2: /stages/stages.0/blocks/blocks.0/mlp/grn/Constant_1_output_0 shape: [2] dtype: int64
# INFO:  output_name.1: /stages/stages.0/blocks/blocks.0/mlp/grn/ReduceSum_output_0 shape: ['batch_size', 1, 1, 512] dtype: float32
# INFO: tf_op_type: reduce_sum
# INFO:  input.1.axis0: shape: () dtype: int64
# INFO:  input.2.axis1: shape: () dtype: int64
# INFO:  input.3.input_tensor: name: tf.math.multiply_15/Mul:0 shape: (None, 56, 56, 512) dtype: <dtype: 'float32'>
# INFO:  input.4.keepdims: val: True
# INFO:  output.1.output: name: tf.math.reduce_sum/Sum:0 shape: (None, 1, 1, 512) dtype: <dtype: 'float32'>
#
# INFO: 35 / 1251
# INFO: onnx_op_type: Pow onnx_op_name: /stages/stages.0/blocks/blocks.0/mlp/grn/Pow_1
# INFO:  input_name.1: /stages/stages.0/blocks/blocks.0/mlp/grn/ReduceSum_output_0 shape: ['batch_size', 1, 1, 512] dtype: float32
# INFO:  input_name.2: /stages/stages.0/blocks/blocks.0/mlp/act/Constant_2_output_0 shape: () dtype: float32
# INFO:  output_name.1: /stages/stages.0/blocks/blocks.0/mlp/grn/Pow_1_output_0 shape: ['batch_size', 1, 1, 512] dtype: float32
# INFO: tf_op_type: pow
# INFO:  input.1.x: name: tf.math.reduce_sum/Sum:0 shape: (None, 1, 1, 512) dtype: <dtype: 'float32'>
# INFO:  input.2.y: shape: () dtype: float32
# INFO:  output.1.output: name: tf.math.pow/Pow:0 shape: (None, 1, 1, 512) dtype: <dtype: 'float32'>
#
# INFO: 36 / 1251
# INFO: onnx_op_type: ReduceMean onnx_op_name: /stages/stages.0/blocks/blocks.0/mlp/grn/ReduceMean
# INFO:  input_name.1: /stages/stages.0/blocks/blocks.0/mlp/grn/Pow_1_output_0 shape: ['batch_size', 1, 1, 512] dtype: float32
# INFO:  output_name.1: /stages/stages.0/blocks/blocks.0/mlp/grn/ReduceMean_output_0 shape: ['batch_size', 1, 1, 1] dtype: float32
# INFO: tf_op_type: reduce_mean
# INFO:  input.1.axis0: val: 3
# INFO:  input.2.input_tensor: name: tf.math.pow/Pow:0 shape: (None, 1, 1, 512) dtype: <dtype: 'float32'>
# INFO:  input.3.keepdims: val: True
# INFO:  output.1.output: name: tf.math.reduce_mean_4/Mean:0 shape: (None, 1, 1, 1) dtype: <dtype: 'float32'>
#
# INFO: 37 / 1251
# INFO: onnx_op_type: Add onnx_op_name: /stages/stages.0/blocks/blocks.0/mlp/grn/Add
# INFO:  input_name.1: /stages/stages.0/blocks/blocks.0/mlp/grn/ReduceMean_output_0 shape: ['batch_size', 1, 1, 1] dtype: float32
# INFO:  input_name.2: /stem/stem.1/Constant_1_output_0 shape: () dtype: float32
# INFO:  output_name.1: /stages/stages.0/blocks/blocks.0/mlp/grn/Add_output_0 shape: ['batch_size', 1, 1, 1] dtype: float32
# INFO: tf_op_type: add
# INFO:  input.1.x: name: tf.math.reduce_mean_4/Mean:0 shape: (None, 1, 1, 1) dtype: <dtype: 'float32'>
# INFO:  input.2.y: shape: () dtype: float32
# INFO:  output.1.output: name: tf.math.add_14/Add:0 shape: (None, 1, 1, 1) dtype: <dtype: 'float32'>
#
# INFO: 38 / 1251
# INFO: onnx_op_type: Div onnx_op_name: /stages/stages.0/blocks/blocks.0/mlp/grn/Div
# INFO:  input_name.1: /stages/stages.0/blocks/blocks.0/mlp/grn/Pow_1_output_0 shape: ['batch_size', 1, 1, 512] dtype: float32
# INFO:  input_name.2: /stages/stages.0/blocks/blocks.0/mlp/grn/Add_output_0 shape: ['batch_size', 1, 1, 1] dtype: float32
# INFO:  output_name.1: /stages/stages.0/blocks/blocks.0/mlp/grn/Div_output_0 shape: ['batch_size', 1, 1, 512] dtype: float32
# INFO: tf_op_type: divide
# INFO:  input.1.x: name: tf.math.pow/Pow:0 shape: (None, 1, 1, 512) dtype: <dtype: 'float32'>
# INFO:  input.2.y: name: tf.math.add_14/Add:0 shape: (None, 1, 1, 1) dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.math.divide_3/truediv:0 shape: (None, 1, 1, 512) dtype: <dtype: 'float32'>
#
# INFO: 39 / 1251
# INFO: onnx_op_type: Mul onnx_op_name: /stages/stages.0/blocks/blocks.0/mlp/grn/Mul
# INFO:  input_name.1: /stages/stages.0/blocks/blocks.0/mlp/act/Mul_1_output_0 shape: ['batch_size', 56, 56, 512] dtype: float32
# INFO:  input_name.2: /stages/stages.0/blocks/blocks.0/mlp/grn/Div_output_0 shape: ['batch_size', 1, 1, 512] dtype: float32
# INFO:  output_name.1: /stages/stages.0/blocks/blocks.0/mlp/grn/Mul_output_0 shape: ['batch_size', 56, 56, 512] dtype: float32
# INFO: tf_op_type: multiply
# INFO:  input.1.x: name: tf.compat.v1.transpose_23/transpose:0 shape: (None, 56, 56, 512) dtype: <dtype: 'float32'>
# INFO:  input.2.y: name: tf.compat.v1.transpose_24/transpose:0 shape: (None, 1, 1, 512) dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.math.multiply_19/Mul:0 shape: (None, 56, 56, 512) dtype: <dtype: 'float32'>
#
# INFO: 40 / 1251
# INFO: onnx_op_type: Mul onnx_op_name: /stages/stages.0/blocks/blocks.0/mlp/grn/Mul_1
# INFO:  input_name.1: onnx::Mul_2328 shape: [1, 1, 1, 512] dtype: float32
# INFO:  input_name.2: /stages/stages.0/blocks/blocks.0/mlp/grn/Mul_output_0 shape: ['batch_size', 56, 56, 512] dtype: float32
# INFO:  output_name.1: /stages/stages.0/blocks/blocks.0/mlp/grn/Mul_1_output_0 shape: ['batch_size', 56, 56, 512] dtype: float32
# INFO: tf_op_type: multiply
# INFO:  input.1.x: shape: (1, 1, 1, 512) dtype: <dtype: 'float32'>
# INFO:  input.2.y: name: tf.compat.v1.transpose_25/transpose:0 shape: (None, 56, 56, 512) dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.math.multiply_21/Mul:0 shape: (None, 56, 56, 512) dtype: <dtype: 'float32'>
#
# INFO: 41 / 1251
# INFO: onnx_op_type: Add onnx_op_name: /stages/stages.0/blocks/blocks.0/mlp/grn/Add_1
# INFO:  input_name.1: onnx::Add_2327 shape: [1, 1, 1, 512] dtype: float32
# INFO:  input_name.2: /stages/stages.0/blocks/blocks.0/mlp/grn/Mul_1_output_0 shape: ['batch_size', 56, 56, 512] dtype: float32
# INFO:  output_name.1: /stages/stages.0/blocks/blocks.0/mlp/grn/Add_1_output_0 shape: ['batch_size', 56, 56, 512] dtype: float32
# INFO: tf_op_type: add
# INFO:  input.1.x: shape: (1, 1, 1, 512) dtype: <dtype: 'float32'>
# INFO:  input.2.y: name: tf.compat.v1.transpose_26/transpose:0 shape: (None, 56, 56, 512) dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.math.add_16/Add:0 shape: (None, 56, 56, 512) dtype: <dtype: 'float32'>
#
# INFO: 42 / 1251
# INFO: onnx_op_type: Add onnx_op_name: /stages/stages.0/blocks/blocks.0/mlp/grn/Add_2
# INFO:  input_name.1: /stages/stages.0/blocks/blocks.0/mlp/act/Mul_1_output_0 shape: ['batch_size', 56, 56, 512] dtype: float32
# INFO:  input_name.2: /stages/stages.0/blocks/blocks.0/mlp/grn/Add_1_output_0 shape: ['batch_size', 56, 56, 512] dtype: float32
# INFO:  output_name.1: /stages/stages.0/blocks/blocks.0/mlp/grn/Add_2_output_0 shape: ['batch_size', 56, 56, 512] dtype: float32
# INFO: tf_op_type: add
# INFO:  input.1.x: name: tf.compat.v1.transpose_27/transpose:0 shape: (None, 56, 56, 512) dtype: <dtype: 'float32'>
# INFO:  input.2.y: name: tf.compat.v1.transpose_28/transpose:0 shape: (None, 56, 56, 512) dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.math.add_18/Add:0 shape: (None, 56, 56, 512) dtype: <dtype: 'float32'>
#
# INFO: 43 / 1251
# INFO: onnx_op_type: MatMul onnx_op_name: /stages/stages.0/blocks/blocks.0/mlp/fc2/MatMul
# INFO:  input_name.1: /stages/stages.0/blocks/blocks.0/mlp/grn/Add_2_output_0 shape: ['batch_size', 56, 56, 512] dtype: float32
# INFO:  input_name.2: onnx::MatMul_2329 shape: [512, 128] dtype: float32
# INFO:  output_name.1: /stages/stages.0/blocks/blocks.0/mlp/fc2/MatMul_output_0 shape: ['batch_size', 56, 56, 128] dtype: float32
# INFO: tf_op_type: matmul
# INFO:  input.1.a: name: tf.math.add_18/Add:0 shape: (None, 56, 56, 512) dtype: <dtype: 'float32'>
# INFO:  input.2.b: shape: (512, 128) dtype: float32
# INFO:  input.3.output_type: name: float32 shape: ()
# INFO:  output.1.output: name: tf.compat.v1.transpose_29/transpose:0 shape: (None, 56, 56, 128) dtype: <dtype: 'float32'>
#
# INFO: 44 / 1251
# INFO: onnx_op_type: Add onnx_op_name: /stages/stages.0/blocks/blocks.0/mlp/fc2/Add
# INFO:  input_name.1: stages.0.blocks.0.mlp.fc2.bias shape: [128] dtype: float32
# INFO:  input_name.2: /stages/stages.0/blocks/blocks.0/mlp/fc2/MatMul_output_0 shape: ['batch_size', 56, 56, 128] dtype: float32
# INFO:  output_name.1: /stages/stages.0/blocks/blocks.0/mlp/fc2/Add_output_0 shape: ['batch_size', 56, 56, 128] dtype: float32
# INFO: tf_op_type: add
# INFO:  input.1.x: name: tf.compat.v1.transpose_30/transpose:0 shape: (None, 56, 56, 128) dtype: <dtype: 'float32'>
# INFO:  input.2.y: shape: (128,) dtype: float32
# INFO:  output.1.output: name: tf.math.add_20/Add:0 shape: (None, 56, 56, 128) dtype: <dtype: 'float32'>
#
# INFO: 45 / 1251
# INFO: onnx_op_type: Transpose onnx_op_name: /stages/stages.0/blocks/blocks.0/Transpose_1
# INFO:  input_name.1: /stages/stages.0/blocks/blocks.0/mlp/fc2/Add_output_0 shape: ['batch_size', 56, 56, 128] dtype: float32
# INFO:  output_name.1: /stages/stages.0/blocks/blocks.0/Transpose_1_output_0 shape: ['batch_size', 128, 56, 56] dtype: float32
# INFO: tf_op_type: transpose_v2
# INFO:  input.1.a: name: tf.math.add_20/Add:0 shape: (None, 56, 56, 128) dtype: <dtype: 'float32'>
# INFO:  input.2.perm: val: [0, 3, 1, 2]
# INFO:  output.1.output: name: tf.compat.v1.transpose_31/transpose:0 shape: (None, 128, 56, 56) dtype: <dtype: 'float32'>
#
# INFO: 46 / 1251
# INFO: onnx_op_type: Add onnx_op_name: /stages/stages.0/blocks/blocks.0/Add
# INFO:  input_name.1: /stages/stages.0/blocks/blocks.0/Transpose_1_output_0 shape: ['batch_size', 128, 56, 56] dtype: float32
# INFO:  input_name.2: /stem/stem.1/Transpose_1_output_0 shape: ['batch_size', 128, 56, 56] dtype: float32
# INFO:  output_name.1: /stages/stages.0/blocks/blocks.0/Add_output_0 shape: ['batch_size', 128, 56, 56] dtype: float32
# INFO: tf_op_type: add
# INFO:  input.1.x: name: tf.compat.v1.transpose_32/transpose:0 shape: (None, 128, 56, 56) dtype: <dtype: 'float32'>
# INFO:  input.2.y: name: tf.compat.v1.transpose_33/transpose:0 shape: (None, 128, 56, 56) dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.math.add_22/Add:0 shape: (None, 128, 56, 56) dtype: <dtype: 'float32'>
#
# INFO: 47 / 1251
# INFO: onnx_op_type: Conv onnx_op_name: /stages/stages.0/blocks/blocks.1/conv_dw/Conv
# INFO:  input_name.1: /stages/stages.0/blocks/blocks.0/Add_output_0 shape: ['batch_size', 128, 56, 56] dtype: float32
# INFO:  input_name.2: stages.0.blocks.1.conv_dw.weight shape: [128, 1, 7, 7] dtype: float32
# INFO:  input_name.3: stages.0.blocks.1.conv_dw.bias shape: [128] dtype: float32
# INFO:  output_name.1: /stages/stages.0/blocks/blocks.1/conv_dw/Conv_output_0 shape: ['batch_size', 128, 56, 56] dtype: float32
# WARNING: This model contains GroupConvolution and is automatically optimized for TFLite, but is not output because saved_model does not support GroupConvolution. If saved_model is needed, specify --disable_group_convolution to retransform the model.
# INFO: tf_op_type: GroupedConvolution2D
# INFO:  input.1.input: name: tf.compat.v1.transpose_34/transpose:0 shape: (None, 56, 56, 128) dtype: <dtype: 'float32'>
# INFO:  input.2.weights: shape: (7, 7, 1, 128) dtype: <dtype: 'float32'>
# INFO:  input.3.bias: shape: (128,) dtype: <dtype: 'float32'>
# INFO:  input.4.strides: val: [1, 1]
# INFO:  input.5.dilations: val: [1, 1]
# INFO:  input.6.padding: val: SAME
# INFO:  input.7.group: val: 128
# INFO:  output.1.output: name: tf.math.add_23/Add:0 shape: (None, 56, 56, 128) dtype: <dtype: 'float32'>
#
# INFO: 48 / 1251
# INFO: onnx_op_type: Transpose onnx_op_name: /stages/stages.0/blocks/blocks.1/Transpose
# INFO:  input_name.1: /stages/stages.0/blocks/blocks.1/conv_dw/Conv_output_0 shape: ['batch_size', 128, 56, 56] dtype: float32
# INFO:  output_name.1: /stages/stages.0/blocks/blocks.1/Transpose_output_0 shape: ['batch_size', 56, 56, 128] dtype: float32
# INFO: tf_op_type: transpose_v2
# INFO:  input.1.a: name: tf.math.add_23/Add:0 shape: (None, 56, 56, 128) dtype: <dtype: 'float32'>
# INFO:  input.2.perm: val: [0, 1, 2, 3]
# INFO:  output.1.output: name: tf.math.add_23/Add:0 shape: (None, 56, 56, 128) dtype: <dtype: 'float32'>
#
# INFO: 49 / 1251
# INFO: onnx_op_type: ReduceMean onnx_op_name: /stages/stages.0/blocks/blocks.1/norm/ReduceMean
# INFO:  input_name.1: /stages/stages.0/blocks/blocks.1/Transpose_output_0 shape: ['batch_size', 56, 56, 128] dtype: float32
# INFO:  output_name.1: /stages/stages.0/blocks/blocks.1/norm/ReduceMean_output_0 shape: ['batch_size', 56, 56, 1] dtype: float32
# INFO: tf_op_type: reduce_mean
# INFO:  input.1.axis0: val: 3
# INFO:  input.2.input_tensor: name: tf.math.add_23/Add:0 shape: (None, 56, 56, 128) dtype: <dtype: 'float32'>
# INFO:  input.3.keepdims: val: True
# INFO:  output.1.output: name: tf.math.reduce_mean_5/Mean:0 shape: (None, 56, 56, 1) dtype: <dtype: 'float32'>
#
# INFO: 50 / 1251
# INFO: onnx_op_type: Sub onnx_op_name: /stages/stages.0/blocks/blocks.1/norm/Sub
# INFO:  input_name.1: /stages/stages.0/blocks/blocks.1/Transpose_output_0 shape: ['batch_size', 56, 56, 128] dtype: float32
# INFO:  input_name.2: /stages/stages.0/blocks/blocks.1/norm/ReduceMean_output_0 shape: ['batch_size', 56, 56, 1] dtype: float32
# INFO:  output_name.1: /stages/stages.0/blocks/blocks.1/norm/Sub_output_0 shape: ['batch_size', 56, 56, 128] dtype: float32
# INFO: tf_op_type: subtract
# INFO:  input.1.x: name: tf.compat.v1.transpose_35/transpose:0 shape: (None, 56, 56, 128) dtype: <dtype: 'float32'>
# INFO:  input.2.y: name: tf.compat.v1.transpose_36/transpose:0 shape: (None, 56, 56, 1) dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.math.subtract_5/Sub:0 shape: (None, 56, 56, 128) dtype: <dtype: 'float32'>
#
# INFO: 51 / 1251
# INFO: onnx_op_type: Pow onnx_op_name: /stages/stages.0/blocks/blocks.1/norm/Pow
# INFO:  input_name.1: /stages/stages.0/blocks/blocks.1/norm/Sub_output_0 shape: ['batch_size', 56, 56, 128] dtype: float32
# INFO:  input_name.2: /stem/stem.1/Constant_output_0 shape: () dtype: float32
# INFO:  output_name.1: /stages/stages.0/blocks/blocks.1/norm/Pow_output_0 shape: ['batch_size', 56, 56, 128] dtype: float32
# INFO: tf_op_type: pow
# INFO:  input.1.x: name: tf.math.subtract_5/Sub:0 shape: (None, 56, 56, 128) dtype: <dtype: 'float32'>
# INFO:  input.2.y: shape: () dtype: float32
# INFO:  output.1.output: name: tf.math.multiply_25/Mul:0 shape: (None, 56, 56, 128) dtype: <dtype: 'float32'>
#
# INFO: 52 / 1251
# INFO: onnx_op_type: ReduceMean onnx_op_name: /stages/stages.0/blocks/blocks.1/norm/ReduceMean_1
# INFO:  input_name.1: /stages/stages.0/blocks/blocks.1/norm/Pow_output_0 shape: ['batch_size', 56, 56, 128] dtype: float32
# INFO:  output_name.1: /stages/stages.0/blocks/blocks.1/norm/ReduceMean_1_output_0 shape: ['batch_size', 56, 56, 1] dtype: float32
# INFO: tf_op_type: reduce_mean
# INFO:  input.1.axis0: val: 3
# INFO:  input.2.input_tensor: name: tf.math.multiply_25/Mul:0 shape: (None, 56, 56, 128) dtype: <dtype: 'float32'>
# INFO:  input.3.keepdims: val: True
# INFO:  output.1.output: name: tf.math.reduce_mean_6/Mean:0 shape: (None, 56, 56, 1) dtype: <dtype: 'float32'>
#
# INFO: 53 / 1251
# INFO: onnx_op_type: Add onnx_op_name: /stages/stages.0/blocks/blocks.1/norm/Add
# INFO:  input_name.1: /stages/stages.0/blocks/blocks.1/norm/ReduceMean_1_output_0 shape: ['batch_size', 56, 56, 1] dtype: float32
# INFO:  input_name.2: /stem/stem.1/Constant_1_output_0 shape: () dtype: float32
# INFO:  output_name.1: /stages/stages.0/blocks/blocks.1/norm/Add_output_0 shape: ['batch_size', 56, 56, 1] dtype: float32
# INFO: tf_op_type: add
# INFO:  input.1.x: name: tf.compat.v1.transpose_37/transpose:0 shape: (None, 56, 56, 1) dtype: <dtype: 'float32'>
# INFO:  input.2.y: shape: () dtype: float32
# INFO:  output.1.output: name: tf.math.add_25/Add:0 shape: (None, 56, 56, 1) dtype: <dtype: 'float32'>
#
# INFO: 54 / 1251
# INFO: onnx_op_type: Sqrt onnx_op_name: /stages/stages.0/blocks/blocks.1/norm/Sqrt
# INFO:  input_name.1: /stages/stages.0/blocks/blocks.1/norm/Add_output_0 shape: ['batch_size', 56, 56, 1] dtype: float32
# INFO:  output_name.1: /stages/stages.0/blocks/blocks.1/norm/Sqrt_output_0 shape: ['batch_size', 56, 56, 1] dtype: float32
# INFO: tf_op_type: sqrt
# INFO:  input.1.x: name: tf.math.add_25/Add:0 shape: (None, 56, 56, 1) dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.math.sqrt_2/Sqrt:0 shape: (None, 56, 56, 1) dtype: <dtype: 'float32'>
#
# INFO: 55 / 1251
# INFO: onnx_op_type: Div onnx_op_name: /stages/stages.0/blocks/blocks.1/norm/Div
# INFO:  input_name.1: /stages/stages.0/blocks/blocks.1/norm/Sub_output_0 shape: ['batch_size', 56, 56, 128] dtype: float32
# INFO:  input_name.2: /stages/stages.0/blocks/blocks.1/norm/Sqrt_output_0 shape: ['batch_size', 56, 56, 1] dtype: float32
# INFO:  output_name.1: /stages/stages.0/blocks/blocks.1/norm/Div_output_0 shape: ['batch_size', 56, 56, 128] dtype: float32
# INFO: tf_op_type: divide
# INFO:  input.1.x: name: tf.compat.v1.transpose_38/transpose:0 shape: (None, 56, 56, 128) dtype: <dtype: 'float32'>
# INFO:  input.2.y: name: tf.compat.v1.transpose_39/transpose:0 shape: (None, 56, 56, 1) dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.math.divide_4/truediv:0 shape: (None, 56, 56, 128) dtype: <dtype: 'float32'>
#
# INFO: 56 / 1251
# INFO: onnx_op_type: Mul onnx_op_name: /stages/stages.0/blocks/blocks.1/norm/Mul
# INFO:  input_name.1: /stages/stages.0/blocks/blocks.1/norm/Div_output_0 shape: ['batch_size', 56, 56, 128] dtype: float32
# INFO:  input_name.2: stages.0.blocks.1.norm.weight shape: [128] dtype: float32
# INFO:  output_name.1: /stages/stages.0/blocks/blocks.1/norm/Mul_output_0 shape: ['batch_size', 56, 56, 128] dtype: float32
# INFO: tf_op_type: multiply
# INFO:  input.1.x: name: tf.compat.v1.transpose_40/transpose:0 shape: (None, 56, 56, 128) dtype: <dtype: 'float32'>
# INFO:  input.2.y: shape: (1, 1, 1, 128) dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.math.multiply_28/Mul:0 shape: (None, 56, 56, 128) dtype: <dtype: 'float32'>
#
# INFO: 57 / 1251
# INFO: onnx_op_type: Add onnx_op_name: /stages/stages.0/blocks/blocks.1/norm/Add_1
# INFO:  input_name.1: /stages/stages.0/blocks/blocks.1/norm/Mul_output_0 shape: ['batch_size', 56, 56, 128] dtype: float32
# INFO:  input_name.2: stages.0.blocks.1.norm.bias shape: [128] dtype: float32
# INFO:  output_name.1: /stages/stages.0/blocks/blocks.1/norm/Add_1_output_0 shape: ['batch_size', 56, 56, 128] dtype: float32
# INFO: tf_op_type: add
# INFO:  input.1.x: name: tf.compat.v1.transpose_41/transpose:0 shape: (None, 56, 56, 128) dtype: <dtype: 'float32'>
# INFO:  input.2.y: shape: (1, 1, 1, 128) dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.math.add_27/Add:0 shape: (None, 56, 56, 128) dtype: <dtype: 'float32'>
#
# INFO: 58 / 1251
# INFO: onnx_op_type: MatMul onnx_op_name: /stages/stages.0/blocks/blocks.1/mlp/fc1/MatMul
# INFO:  input_name.1: /stages/stages.0/blocks/blocks.1/norm/Add_1_output_0 shape: ['batch_size', 56, 56, 128] dtype: float32
# INFO:  input_name.2: onnx::MatMul_2330 shape: [128, 512] dtype: float32
# INFO:  output_name.1: /stages/stages.0/blocks/blocks.1/mlp/fc1/MatMul_output_0 shape: ['batch_size', 56, 56, 512] dtype: float32
# INFO: tf_op_type: matmul
# INFO:  input.1.a: name: tf.math.add_27/Add:0 shape: (None, 56, 56, 128) dtype: <dtype: 'float32'>
# INFO:  input.2.b: shape: (128, 512) dtype: float32
# INFO:  input.3.output_type: name: float32 shape: ()
# INFO:  output.1.output: name: tf.compat.v1.transpose_42/transpose:0 shape: (None, 56, 56, 512) dtype: <dtype: 'float32'>
#
# INFO: 59 / 1251
# INFO: onnx_op_type: Add onnx_op_name: /stages/stages.0/blocks/blocks.1/mlp/fc1/Add
# INFO:  input_name.1: stages.0.blocks.1.mlp.fc1.bias shape: [512] dtype: float32
# INFO:  input_name.2: /stages/stages.0/blocks/blocks.1/mlp/fc1/MatMul_output_0 shape: ['batch_size', 56, 56, 512] dtype: float32
# INFO:  output_name.1: /stages/stages.0/blocks/blocks.1/mlp/fc1/Add_output_0 shape: ['batch_size', 56, 56, 512] dtype: float32
# INFO: tf_op_type: add
# INFO:  input.1.x: name: tf.compat.v1.transpose_43/transpose:0 shape: (None, 56, 56, 512) dtype: <dtype: 'float32'>
# INFO:  input.2.y: shape: (512,) dtype: float32
# INFO:  output.1.output: name: tf.math.add_29/Add:0 shape: (None, 56, 56, 512) dtype: <dtype: 'float32'>
#
# INFO: 60 / 1251
# INFO: onnx_op_type: Div onnx_op_name: /stages/stages.0/blocks/blocks.1/mlp/act/Div
# INFO:  input_name.1: /stages/stages.0/blocks/blocks.1/mlp/fc1/Add_output_0 shape: ['batch_size', 56, 56, 512] dtype: float32
# INFO:  input_name.2: /stages/stages.0/blocks/blocks.0/mlp/act/Constant_output_0 shape: () dtype: float32
# INFO:  output_name.1: /stages/stages.0/blocks/blocks.1/mlp/act/Div_output_0 shape: ['batch_size', 56, 56, 512] dtype: float32
# INFO: tf_op_type: divide
# INFO:  input.1.x: name: tf.compat.v1.transpose_44/transpose:0 shape: (None, 56, 56, 512) dtype: <dtype: 'float32'>
# INFO:  input.2.y: shape: () dtype: float32
# INFO:  output.1.output: name: tf.math.divide_5/truediv:0 shape: (None, 56, 56, 512) dtype: <dtype: 'float32'>
#
# INFO: 61 / 1251
# INFO: onnx_op_type: Erf onnx_op_name: /stages/stages.0/blocks/blocks.1/mlp/act/Erf
# INFO:  input_name.1: /stages/stages.0/blocks/blocks.1/mlp/act/Div_output_0 shape: ['batch_size', 56, 56, 512] dtype: float32
# INFO:  output_name.1: /stages/stages.0/blocks/blocks.1/mlp/act/Erf_output_0 shape: ['batch_size', 56, 56, 512] dtype: float32
# INFO: tf_op_type: erf
# ...
# INFO:  output_name.1: /stages/stages.3/blocks/blocks.2/mlp/grn/Mul_output_0 shape: ['batch_size', 7, 7, 4096] dtype: float32
# INFO: tf_op_type: multiply
# INFO:  input.1.x: name: tf.compat.v1.transpose_1246/transpose:0 shape: (None, 7, 7, 4096) dtype: <dtype: 'float32'>
# INFO:  input.2.y: name: tf.compat.v1.transpose_1247/transpose:0 shape: (None, 1, 1, 4096) dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.math.multiply_699/Mul:0 shape: (None, 7, 7, 4096) dtype: <dtype: 'float32'>
#
# INFO: 1231 / 1251
# INFO: onnx_op_type: Mul onnx_op_name: /stages/stages.3/blocks/blocks.2/mlp/grn/Mul_1
# INFO:  input_name.1: onnx::Mul_2503 shape: [1, 1, 1, 4096] dtype: float32
# INFO:  input_name.2: /stages/stages.3/blocks/blocks.2/mlp/grn/Mul_output_0 shape: ['batch_size', 7, 7, 4096] dtype: float32
# INFO:  output_name.1: /stages/stages.3/blocks/blocks.2/mlp/grn/Mul_1_output_0 shape: ['batch_size', 7, 7, 4096] dtype: float32
# INFO: tf_op_type: multiply
# INFO:  input.1.x: shape: (1, 1, 1, 4096) dtype: <dtype: 'float32'>
# INFO:  input.2.y: name: tf.compat.v1.transpose_1248/transpose:0 shape: (None, 7, 7, 4096) dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.math.multiply_701/Mul:0 shape: (None, 7, 7, 4096) dtype: <dtype: 'float32'>
#
# INFO: 1232 / 1251
# INFO: onnx_op_type: Add onnx_op_name: /stages/stages.3/blocks/blocks.2/mlp/grn/Add_1
# INFO:  input_name.1: onnx::Add_2502 shape: [1, 1, 1, 4096] dtype: float32
# INFO:  input_name.2: /stages/stages.3/blocks/blocks.2/mlp/grn/Mul_1_output_0 shape: ['batch_size', 7, 7, 4096] dtype: float32
# INFO:  output_name.1: /stages/stages.3/blocks/blocks.2/mlp/grn/Add_1_output_0 shape: ['batch_size', 7, 7, 4096] dtype: float32
# INFO: tf_op_type: add
# INFO:  input.1.x: shape: (1, 1, 1, 4096) dtype: <dtype: 'float32'>
# INFO:  input.2.y: name: tf.compat.v1.transpose_1249/transpose:0 shape: (None, 7, 7, 4096) dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.math.add_661/Add:0 shape: (None, 7, 7, 4096) dtype: <dtype: 'float32'>
#
# INFO: 1233 / 1251
# INFO: onnx_op_type: Add onnx_op_name: /stages/stages.3/blocks/blocks.2/mlp/grn/Add_2
# INFO:  input_name.1: /stages/stages.3/blocks/blocks.2/mlp/act/Mul_1_output_0 shape: ['batch_size', 7, 7, 4096] dtype: float32
# INFO:  input_name.2: /stages/stages.3/blocks/blocks.2/mlp/grn/Add_1_output_0 shape: ['batch_size', 7, 7, 4096] dtype: float32
# INFO:  output_name.1: /stages/stages.3/blocks/blocks.2/mlp/grn/Add_2_output_0 shape: ['batch_size', 7, 7, 4096] dtype: float32
# INFO: tf_op_type: add
# INFO:  input.1.x: name: tf.compat.v1.transpose_1250/transpose:0 shape: (None, 7, 7, 4096) dtype: <dtype: 'float32'>
# INFO:  input.2.y: name: tf.compat.v1.transpose_1251/transpose:0 shape: (None, 7, 7, 4096) dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.math.add_663/Add:0 shape: (None, 7, 7, 4096) dtype: <dtype: 'float32'>
#
# INFO: 1234 / 1251
# INFO: onnx_op_type: MatMul onnx_op_name: /stages/stages.3/blocks/blocks.2/mlp/fc2/MatMul
# INFO:  input_name.1: /stages/stages.3/blocks/blocks.2/mlp/grn/Add_2_output_0 shape: ['batch_size', 7, 7, 4096] dtype: float32
# INFO:  input_name.2: onnx::MatMul_2504 shape: [4096, 1024] dtype: float32
# INFO:  output_name.1: /stages/stages.3/blocks/blocks.2/mlp/fc2/MatMul_output_0 shape: ['batch_size', 7, 7, 1024] dtype: float32
# INFO: tf_op_type: matmul
# INFO:  input.1.a: name: tf.math.add_663/Add:0 shape: (None, 7, 7, 4096) dtype: <dtype: 'float32'>
# INFO:  input.2.b: shape: (4096, 1024) dtype: float32
# INFO:  input.3.output_type: name: float32 shape: ()
# INFO:  output.1.output: name: tf.compat.v1.transpose_1252/transpose:0 shape: (None, 7, 7, 1024) dtype: <dtype: 'float32'>
#
# INFO: 1235 / 1251
# INFO: onnx_op_type: Add onnx_op_name: /stages/stages.3/blocks/blocks.2/mlp/fc2/Add
# INFO:  input_name.1: stages.3.blocks.2.mlp.fc2.bias shape: [1024] dtype: float32
# INFO:  input_name.2: /stages/stages.3/blocks/blocks.2/mlp/fc2/MatMul_output_0 shape: ['batch_size', 7, 7, 1024] dtype: float32
# INFO:  output_name.1: /stages/stages.3/blocks/blocks.2/mlp/fc2/Add_output_0 shape: ['batch_size', 7, 7, 1024] dtype: float32
# INFO: tf_op_type: add
# INFO:  input.1.x: name: tf.compat.v1.transpose_1253/transpose:0 shape: (None, 7, 7, 1024) dtype: <dtype: 'float32'>
# INFO:  input.2.y: shape: (1024,) dtype: float32
# INFO:  output.1.output: name: tf.math.add_665/Add:0 shape: (None, 7, 7, 1024) dtype: <dtype: 'float32'>
#
# INFO: 1236 / 1251
# INFO: onnx_op_type: Transpose onnx_op_name: /stages/stages.3/blocks/blocks.2/Transpose_1
# INFO:  input_name.1: /stages/stages.3/blocks/blocks.2/mlp/fc2/Add_output_0 shape: ['batch_size', 7, 7, 1024] dtype: float32
# INFO:  output_name.1: /stages/stages.3/blocks/blocks.2/Transpose_1_output_0 shape: ['batch_size', 1024, 7, 7] dtype: float32
# INFO: tf_op_type: transpose_v2
# INFO:  input.1.a: name: tf.math.add_665/Add:0 shape: (None, 7, 7, 1024) dtype: <dtype: 'float32'>
# INFO:  input.2.perm: val: [0, 3, 1, 2]
# INFO:  output.1.output: name: tf.compat.v1.transpose_1254/transpose:0 shape: (None, 1024, 7, 7) dtype: <dtype: 'float32'>
#
# INFO: 1237 / 1251
# INFO: onnx_op_type: Add onnx_op_name: /stages/stages.3/blocks/blocks.2/Add
# INFO:  input_name.1: /stages/stages.3/blocks/blocks.2/Transpose_1_output_0 shape: ['batch_size', 1024, 7, 7] dtype: float32
# INFO:  input_name.2: /stages/stages.3/blocks/blocks.1/Add_output_0 shape: ['batch_size', 1024, 7, 7] dtype: float32
# INFO:  output_name.1: /stages/stages.3/blocks/blocks.2/Add_output_0 shape: ['batch_size', 1024, 7, 7] dtype: float32
# INFO: tf_op_type: add
# INFO:  input.1.x: name: tf.math.add_649/Add:0 shape: (None, 7, 7, 1024) dtype: <dtype: 'float32'>
# INFO:  input.2.y: name: tf.compat.v1.transpose_1255/transpose:0 shape: (None, 7, 7, 1024) dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.math.add_667/Add:0 shape: (None, 7, 7, 1024) dtype: <dtype: 'float32'>
#
# INFO: 1238 / 1251
# INFO: onnx_op_type: GlobalAveragePool onnx_op_name: /head/global_pool/pool/GlobalAveragePool
# INFO:  input_name.1: /stages/stages.3/blocks/blocks.2/Add_output_0 shape: ['batch_size', 1024, 7, 7] dtype: float32
# INFO:  output_name.1: /head/global_pool/pool/GlobalAveragePool_output_0 shape: ['batch_size', 1024, 1, 1] dtype: float32
# INFO: tf_op_type: reduce_mean
# INFO:  input.1.input_tensor: name: tf.math.add_667/Add:0 shape: (None, 7, 7, 1024) dtype: <dtype: 'float32'>
# INFO:  input.2.axis: val: [1, 2]
# INFO:  input.3.keepdims: val: True
# INFO:  output.1.output: name: tf.math.reduce_mean_116/Mean:0 shape: (None, 1, 1, 1024) dtype: <dtype: 'float32'>
#
# INFO: 1239 / 1251
# INFO: onnx_op_type: Transpose onnx_op_name: /head/norm/Transpose
# INFO:  input_name.1: /head/global_pool/pool/GlobalAveragePool_output_0 shape: ['batch_size', 1024, 1, 1] dtype: float32
# INFO:  output_name.1: /head/norm/Transpose_output_0 shape: ['batch_size', 1, 1, 1024] dtype: float32
# INFO: tf_op_type: transpose_v2
# INFO:  input.1.a: name: tf.math.reduce_mean_116/Mean:0 shape: (None, 1, 1, 1024) dtype: <dtype: 'float32'>
# INFO:  input.2.perm: val: [0, 1, 2, 3]
# INFO:  output.1.output: name: tf.math.reduce_mean_116/Mean:0 shape: (None, 1, 1, 1024) dtype: <dtype: 'float32'>
#
# INFO: 1240 / 1251
# INFO: onnx_op_type: ReduceMean onnx_op_name: /head/norm/ReduceMean
# INFO:  input_name.1: /head/norm/Transpose_output_0 shape: ['batch_size', 1, 1, 1024] dtype: float32
# INFO:  output_name.1: /head/norm/ReduceMean_output_0 shape: ['batch_size', 1, 1, 1] dtype: float32
# INFO: tf_op_type: reduce_mean
# INFO:  input.1.axis0: val: 3
# INFO:  input.2.input_tensor: name: tf.math.reduce_mean_116/Mean:0 shape: (None, 1, 1, 1024) dtype: <dtype: 'float32'>
# INFO:  input.3.keepdims: val: True
# INFO:  output.1.output: name: tf.math.reduce_mean_117/Mean:0 shape: (None, 1, 1, 1) dtype: <dtype: 'float32'>
#
# INFO: 1241 / 1251
# INFO: onnx_op_type: Sub onnx_op_name: /head/norm/Sub
# INFO:  input_name.1: /head/norm/Transpose_output_0 shape: ['batch_size', 1, 1, 1024] dtype: float32
# INFO:  input_name.2: /head/norm/ReduceMean_output_0 shape: ['batch_size', 1, 1, 1] dtype: float32
# INFO:  output_name.1: /head/norm/Sub_output_0 shape: ['batch_size', 1, 1, 1024] dtype: float32
# INFO: tf_op_type: subtract
# INFO:  input.1.x: name: tf.math.reduce_mean_116/Mean:0 shape: (None, 1, 1, 1024) dtype: <dtype: 'float32'>
# INFO:  input.2.y: name: tf.math.reduce_mean_117/Mean:0 shape: (None, 1, 1, 1) dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.math.subtract_80/Sub:0 shape: (None, 1, 1, 1024) dtype: <dtype: 'float32'>
#
# INFO: 1242 / 1251
# INFO: onnx_op_type: Pow onnx_op_name: /head/norm/Pow
# INFO:  input_name.1: /head/norm/Sub_output_0 shape: ['batch_size', 1, 1, 1024] dtype: float32
# INFO:  input_name.2: /stem/stem.1/Constant_output_0 shape: () dtype: float32
# INFO:  output_name.1: /head/norm/Pow_output_0 shape: ['batch_size', 1, 1, 1024] dtype: float32
# INFO: tf_op_type: pow
# INFO:  input.1.x: name: tf.math.subtract_80/Sub:0 shape: (None, 1, 1, 1024) dtype: <dtype: 'float32'>
# INFO:  input.2.y: shape: () dtype: float32
# INFO:  output.1.output: name: tf.math.multiply_705/Mul:0 shape: (None, 1, 1, 1024) dtype: <dtype: 'float32'>
#
# INFO: 1243 / 1251
# INFO: onnx_op_type: ReduceMean onnx_op_name: /head/norm/ReduceMean_1
# INFO:  input_name.1: /head/norm/Pow_output_0 shape: ['batch_size', 1, 1, 1024] dtype: float32
# INFO:  output_name.1: /head/norm/ReduceMean_1_output_0 shape: ['batch_size', 1, 1, 1] dtype: float32
# INFO: tf_op_type: reduce_mean
# INFO:  input.1.axis0: val: 3
# INFO:  input.2.input_tensor: name: tf.math.multiply_705/Mul:0 shape: (None, 1, 1, 1024) dtype: <dtype: 'float32'>
# INFO:  input.3.keepdims: val: True
# INFO:  output.1.output: name: tf.math.reduce_mean_118/Mean:0 shape: (None, 1, 1, 1) dtype: <dtype: 'float32'>
#
# INFO: 1244 / 1251
# INFO: onnx_op_type: Add onnx_op_name: /head/norm/Add
# INFO:  input_name.1: /head/norm/ReduceMean_1_output_0 shape: ['batch_size', 1, 1, 1] dtype: float32
# INFO:  input_name.2: /stem/stem.1/Constant_1_output_0 shape: () dtype: float32
# INFO:  output_name.1: /head/norm/Add_output_0 shape: ['batch_size', 1, 1, 1] dtype: float32
# INFO: tf_op_type: add
# INFO:  input.1.x: name: tf.math.reduce_mean_118/Mean:0 shape: (None, 1, 1, 1) dtype: <dtype: 'float32'>
# INFO:  input.2.y: shape: () dtype: float32
# INFO:  output.1.output: name: tf.math.add_668/Add:0 shape: (None, 1, 1, 1) dtype: <dtype: 'float32'>
#
# INFO: 1245 / 1251
# INFO: onnx_op_type: Sqrt onnx_op_name: /head/norm/Sqrt
# INFO:  input_name.1: /head/norm/Add_output_0 shape: ['batch_size', 1, 1, 1] dtype: float32
# INFO:  output_name.1: /head/norm/Sqrt_output_0 shape: ['batch_size', 1, 1, 1] dtype: float32
# INFO: tf_op_type: sqrt
# INFO:  input.1.x: name: tf.math.add_668/Add:0 shape: (None, 1, 1, 1) dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.math.sqrt_40/Sqrt:0 shape: (None, 1, 1, 1) dtype: <dtype: 'float32'>
#
# INFO: 1246 / 1251
# INFO: onnx_op_type: Div onnx_op_name: /head/norm/Div
# INFO:  input_name.1: /head/norm/Sub_output_0 shape: ['batch_size', 1, 1, 1024] dtype: float32
# INFO:  input_name.2: /head/norm/Sqrt_output_0 shape: ['batch_size', 1, 1, 1] dtype: float32
# INFO:  output_name.1: /head/norm/Div_output_0 shape: ['batch_size', 1, 1, 1024] dtype: float32
# INFO: tf_op_type: divide
# INFO:  input.1.x: name: tf.math.subtract_80/Sub:0 shape: (None, 1, 1, 1024) dtype: <dtype: 'float32'>
# INFO:  input.2.y: name: tf.math.sqrt_40/Sqrt:0 shape: (None, 1, 1, 1) dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.math.divide_112/truediv:0 shape: (None, 1, 1, 1024) dtype: <dtype: 'float32'>
#
# INFO: 1247 / 1251
# INFO: onnx_op_type: Mul onnx_op_name: /head/norm/Mul
# INFO:  input_name.1: /head/norm/Div_output_0 shape: ['batch_size', 1, 1, 1024] dtype: float32
# INFO:  input_name.2: head.norm.weight shape: [1024] dtype: float32
# INFO:  output_name.1: /head/norm/Mul_output_0 shape: ['batch_size', 1, 1, 1024] dtype: float32
# INFO: tf_op_type: multiply
# INFO:  input.1.x: name: tf.math.divide_112/truediv:0 shape: (None, 1, 1, 1024) dtype: <dtype: 'float32'>
# INFO:  input.2.y: shape: (1, 1, 1, 1024) dtype: float32
# INFO:  output.1.output: name: tf.math.multiply_707/Mul:0 shape: (None, 1, 1, 1024) dtype: <dtype: 'float32'>
#
# INFO: 1248 / 1251
# INFO: onnx_op_type: Add onnx_op_name: /head/norm/Add_1
# INFO:  input_name.1: /head/norm/Mul_output_0 shape: ['batch_size', 1, 1, 1024] dtype: float32
# INFO:  input_name.2: head.norm.bias shape: [1024] dtype: float32
# INFO:  output_name.1: /head/norm/Add_1_output_0 shape: ['batch_size', 1, 1, 1024] dtype: float32
# INFO: tf_op_type: add
# INFO:  input.1.x: name: tf.math.multiply_707/Mul:0 shape: (None, 1, 1, 1024) dtype: <dtype: 'float32'>
# INFO:  input.2.y: shape: (1, 1, 1, 1024) dtype: float32
# INFO:  output.1.output: name: tf.math.add_669/Add:0 shape: (None, 1, 1, 1024) dtype: <dtype: 'float32'>
#
# INFO: 1249 / 1251
# INFO: onnx_op_type: Transpose onnx_op_name: /head/norm/Transpose_1
# INFO:  input_name.1: /head/norm/Add_1_output_0 shape: ['batch_size', 1, 1, 1024] dtype: float32
# INFO:  output_name.1: /head/norm/Transpose_1_output_0 shape: ['batch_size', 1024, 1, 1] dtype: float32
# INFO: tf_op_type: transpose_v2
# INFO:  input.1.a: name: tf.math.add_669/Add:0 shape: (None, 1, 1, 1024) dtype: <dtype: 'float32'>
# INFO:  input.2.perm: val: [0, 3, 1, 2]
# INFO:  output.1.output: name: tf.compat.v1.transpose_1256/transpose:0 shape: (None, 1024, 1, 1) dtype: <dtype: 'float32'>
#
# INFO: 1250 / 1251
# INFO: onnx_op_type: Flatten onnx_op_name: /head/flatten/Flatten
# INFO:  input_name.1: /head/norm/Transpose_1_output_0 shape: ['batch_size', 1024, 1, 1] dtype: float32
# INFO:  output_name.1: /head/flatten/Flatten_output_0 shape: ['batch_size', 1024] dtype: float32
# INFO: tf_op_type: reshape
# INFO:  input.1.tensor: name: tf.compat.v1.transpose_1256/transpose:0 shape: (None, 1024, 1, 1) dtype: <dtype: 'float32'>
# INFO:  input.2.shape:
# INFO:  output.1.output: name: tf.reshape/Reshape:0 shape: (None, 1024) dtype: <dtype: 'float32'>
#
# INFO: 1251 / 1251
# INFO: onnx_op_type: Gemm onnx_op_name: /head/fc/Gemm
# INFO:  input_name.1: /head/flatten/Flatten_output_0 shape: ['batch_size', 1024] dtype: float32
# INFO:  input_name.2: head.fc.weight shape: [1000, 1024] dtype: float32
# INFO:  input_name.3: head.fc.bias shape: [1000] dtype: float32
# INFO:  output_name.1: output shape: ['batch_size', 1000] dtype: float32
# INFO: tf_op_type: matmul
# INFO:  input.1.x: name: Placeholder:0 shape: (None, 1024) dtype: <dtype: 'float32'>
# INFO:  input.2.y: shape: (1024, 1000) dtype: <dtype: 'float32'>
# INFO:  input.3.z: shape: (1000,) dtype: <dtype: 'float32'>
# INFO:  input.4.alpha: val: 1.0
# INFO:  input.5.beta: val: 1.0
# INFO:  output.1.output: name: tf.__operators__.add/AddV2:0 shape: (None, 1000) dtype: <dtype: 'float32'>
#
# saved_model output started ==========================================================
# WARNING: This model contains GroupConvolution and is automatically optimized for TFLite, but is not output because saved_model does not support GroupConvolution. If saved_model is needed, specify --disable_group_convolution to retransform the model.
# Summary on the non-converted ops:
# ---------------------------------
#  * Accepted dialects: tfl, builtin, func
#  * Non-Converted Ops: 495, Total Ops 1559, % non-converted = 31.75 %
#  * 459 ARITH ops, 36 TF ops
#
# - arith.constant:  459 occurrences  (f32: 455, i32: 4)
#
#
#
# - tf.Erf:   36 occurrences  (f32: 36)
#   (f32: 36)
#   (f32: 262)
#   (f32: 7)
#   (f32: 33)
#   (f32: 36)
#   (f32: 109)
#   (f32: 119)
#   (f32: 303)
#   (f32: 1)
#   (f32: 41)
#   (f32: 36)
#   (f32: 41)
#   (f32: 36)
#   (f32: 1)
# Float32 tflite output complete!
# Summary on the non-converted ops:
# ---------------------------------
#  * Accepted dialects: tfl, builtin, func
#  * Non-Converted Ops: 495, Total Ops 2014, % non-converted = 24.58 %
#  * 459 ARITH ops, 36 TF ops
#
# - arith.constant:  459 occurrences  (f16: 455, i32: 4)
#
#
#
# - tf.Erf:   36 occurrences  (f32: 36)
#   (f32: 36)
#   (f32: 262)
#   (f32: 7)
#   (f32: 33)
#   (f32: 455)
#   (f32: 36)
#   (f32: 109)
#   (f32: 119)
#   (f32: 303)
#   (f32: 1)
#   (f32: 41)
#   (f32: 36)
#   (f32: 41)
#   (f32: 36)
#   (f32: 1)
# Float16 tflite output complete!
